# %%
pip install twython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: twython in /usr/local/lib/python3.7/dist-packages (3.9.1)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from twython) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from twython) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.4.0->twython) (3.2.2)

# %%
from twython import Twython

# %%
import pandas as pd

# %%
CONSUMER_KEY = '0pJRCT1emkOcrtxHl7lMN4N5A'
CONSUMER_SECRET = 'IS4Gxcx1aQ1c5Hyei5PSePLS37IcVmYBT8Qt1t4IOxmLIxJD42'

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET)

# %%
results=twitter.search(q="Elon Musk",count=100)

# %%
results
# Out:
# {'statuses': [{'created_at': 'Thu Nov 03 18:29:24 +0000 2022',
#    'id': 1588236922278842369,
#    'id_str': '1588236922278842369',
#    'text': 'RT @Julian_Epp: Looks like Twitter is changing the verification symbol too. Google “Elon Musk emerald” for more info https://t.co/ZeNQgGXP18',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Julian_Epp',
#       'name': 'Jules',
#       'id': 219505926,
#       'id_str': '219505926',
#       'indices': [3, 14]}],
#     'urls': [],
#     'media': [{'id': 1587530040962695175,
#       'id_str': '1587530040962695175',
#       'indices': [117, 140],
#       'media_url': 'http://pbs.twimg.com/media/FggKKUHXwAc7YMI.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FggKKUHXwAc7YMI.jpg',
#       'url': 'https://t.co/ZeNQgGXP18',
#       'display_url': 'pic.twitter.com/ZeNQgGXP18',
#       'expanded_url': 'https://twitter.com/Julian_Epp/status/1587530044292964352/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1169, 'h': 736, 'resize': 'fit'},
#        'medium': {'w': 1169, 'h': 736, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 428, 'resize': 'fit'}},
#       'source_status_id': 1587530044292964352,
#       'source_status_id_str': '1587530044292964352',
#       'source_user_id': 219505926,
#       'source_user_id_str': '219505926'}]},
#    'extended_entities': {'media': [{'id': 1587530040962695175,
#       'id_str': '1587530040962695175',
#       'indices': [117, 140],
#       'media_url': 'http://pbs.twimg.com/media/FggKKUHXwAc7YMI.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FggKKUHXwAc7YMI.jpg',
#       'url': 'https://t.co/ZeNQgGXP18',
#       'display_url': 'pic.twitter.com/ZeNQgGXP18',
#       'expanded_url': 'https://twitter.com/Julian_Epp/status/1587530044292964352/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1169, 'h': 736, 'resize': 'fit'},
#        'medium': {'w': 1169, 'h': 736, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 428, 'resize': 'fit'}},
#       'source_status_id': 1587530044292964352,
#       'source_status_id_str': '1587530044292964352',
#       'source_user_id': 219505926,
#       'source_user_id_str': '219505926'}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 805883214862675968,
#     'id_str': '805883214862675968',
#     'name': 'I simply sail the ship',
#     'screen_name': 'CadetJamieD',
#     'location': 'England, United Kingdom',
#     'description': 'Enlglish, bisexual. She/her. 18+, minors dni. Will reblog/post NSFW content. Pro-shipper/anti-harassment',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 62,
#     'friends_count': 263,
#     'listed_count': 0,
#     'created_at': 'Mon Dec 05 21:15:05 +0000 2016',
#     'favourites_count': 129149,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 18101,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1169722891111473153/LnUEhhhD_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1169722891111473153/LnUEhhhD_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805883214862675968/1616513403',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Nov 01 19:40:32 +0000 2022',
#     'id': 1587530044292964352,
#     'id_str': '1587530044292964352',
#     'text': 'Looks like Twitter is changing the verification symbol too. Google “Elon Musk emerald” for more info https://t.co/ZeNQgGXP18',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1587530040962695175,
#        'id_str': '1587530040962695175',
#        'indices': [101, 124],
#        'media_url': 'http://pbs.twimg.com/media/FggKKUHXwAc7YMI.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FggKKUHXwAc7YMI.jpg',
#        'url': 'https://t.co/ZeNQgGXP18',
#        'display_url': 'pic.twitter.com/ZeNQgGXP18',
#        'expanded_url': 'https://twitter.com/Julian_Epp/status/1587530044292964352/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1169, 'h': 736, 'resize': 'fit'},
#         'medium': {'w': 1169, 'h': 736, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 428, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1587530040962695175,
#        'id_str': '1587530040962695175',
#        'indices': [101, 124],
#        'media_url': 'http://pbs.twimg.com/media/FggKKUHXwAc7YMI.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FggKKUHXwAc7YMI.jpg',
#        'url': 'https://t.co/ZeNQgGXP18',
#        'display_url': 'pic.twitter.com/ZeNQgGXP18',
#        'expanded_url': 'https://twitter.com/Julian_Epp/status/1587530044292964352/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1169, 'h': 736, 'resize': 'fit'},
#         'medium': {'w': 1169, 'h': 736, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 428, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 219505926,
#      'id_str': '219505926',
#      'name': 'Jules',
#      'screen_name': 'Julian_Epp',
#      'location': '',
#      'description': 'Tweeted in front of a live studio audience / Words @NewRepublic, @TheNation, @DissentMag',
#      'url': 'https://t.co/pFSbt0MQ2k',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/pFSbt0MQ2k',
#          'expanded_url': 'https://twitter.com',
#          'display_url': 'twitter.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 33600,
#      'friends_count': 1406,
#      'listed_count': 110,
#      'created_at': 'Thu Nov 25 01:50:41 +0000 2010',
#      'favourites_count': 651707,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 10065,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'ABB8C2',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1162893472740913153/I9Uq64-r_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1162893472740913153/I9Uq64-r_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/219505926/1570816151',
#      'profile_link_color': '000000',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'regular',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 15972,
#     'favorite_count': 128781,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 15972,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 03 18:29:24 +0000 2022',
#    'id': 1588236921788145664,
#    'id_str': '1588236921788145664',
#    'text': 'RT @blogjam: I would like to pay tribute to my good friend Simon, permanently banned from Twitter after switching his display name to be El…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'blogjam',
#       'name': 'Fraser Lewry',
#       'id': 1795971,
#       'id_str': '1795971',
#       'indices': [3, 11]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 10648942,
#     'id_str': '10648942',
#     'name': 'Jason Shiflet 🏳️\u200d🌈',
#     'screen_name': 'therealjshiflet',
#     'location': 'Dallas, TX',
#     'description': "ISFP. Texan by birth. Seattleite at heart. IT nerd by day, but by night? I'm also an IT nerd. 🏳️\u200d🌈♋️",
#     'url': 'https://t.co/TWCpW4Mko3',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/TWCpW4Mko3',
#         'expanded_url': 'http://shiflet.me',
#         'display_url': 'shiflet.me',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 123,
#     'friends_count': 393,
#     'listed_count': 2,
#     'created_at': 'Tue Nov 27 06:16:47 +0000 2007',
#     'favourites_count': 48932,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 9198,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1078417675095867399/beSKFSC4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1078417675095867399/beSKFSC4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/10648942/1547523553',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Nov 03 09:56:04 +0000 2022',
#     'id': 1588107736298180608,
#     'id_str': '1588107736298180608',
#     'text': 'I would like to pay tribute to my good friend Simon, permanently banned from Twitter after switching his display na… https://t.co/164FqyUSOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/164FqyUSOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1588107736298180608',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1795971,
#      'id_str': '1795971',
#      'name': 'Fraser Lewry',
#      'screen_name': 'blogjam',
#      'location': 'Oamaru, Aotearoa',
#      'description': 'Online Editor @ClassicRockMag, bits for @ProgMagazineUK, @MetalHammer. Previously BERG, Word Magazine, Xfm. Reintegrating Kiwi. Pluviophile. Kitten Jesus.',
#      'url': 'https://t.co/GRuO8Mo9iJ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/GRuO8Mo9iJ',
#          'expanded_url': 'https://lewry.com/',
#          'display_url': 'lewry.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2164,
#      'friends_count': 667,
#      'listed_count': 55,
#      'created_at': 'Wed Mar 21 21:00:17 +0000 2007',
#      'favourites_count': 3693,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 4557,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '204A87',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1586588754051227649/0MDr46N__normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1586588754051227649/0MDr46N__normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1795971/1641101965',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FAC409',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2490,
#     'favorite_count': 18778,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2490,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 03 18:29:24 +0000 2022',
#    'id': 1588236921309904899,
#    'id_str': '1588236921309904899',
#    'text': 'RT @blogjam: I would like to pay tribute to my good friend Simon, permanently banned from Twitter after switching his display name to be El…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'blogjam',
#       'name': 'Fraser Lewry',
#       'id': 1795971,
#       'id_str': '1795971',
#       'indices': [3, 11]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 240855035,
#     'id_str': '240855035',
#     'name': 'Daibhid Ceannaideach',
#     'screen_name': 'daibhidc',
#     'location': '',
#     'description': "Scottish skiffy geek. Big fan of Doctor Who and Discworld. Anxiety disorder, autistic spectrum, he/him. I'm a key worker, but I can't always work a key.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 245,
#     'friends_count': 213,
#     'listed_count': 19,
#     'created_at': 'Thu Jan 20 22:19:45 +0000 2011',
#     'favourites_count': 20693,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 59840,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '642D8B',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1479500054440382466/nEYYhuJs_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1479500054440382466/nEYYhuJs_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/240855035/1468413490',
#     'profile_link_color': '642D8B',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '7AC3EE',
#     'profile_text_color': '3D1957',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Nov 03 09:56:04 +0000 2022',
#     'id': 1588107736298180608,
#     'id_str': '1588107736298180608',
#     'text': 'I would like to pay tribute to my good friend Simon, permanently banned from Twitter after switching his display na… https://t.co/164FqyUSOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/164FqyUSOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1588107736298180608',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1795971,
#      'id_str': '1795971',
#      'name': 'Fraser Lewry',
#      'screen_name': 'blogjam',
#      'location': 'Oamaru, Aotearoa',
#      'description': 'Online Editor @ClassicRockMag, bits for @ProgMagazineUK, @MetalHammer. Previously BERG, Word Magazine, Xfm. Reintegrating Kiwi. Pluviophile. Kitten Jesus.',
#      'url': 'https://t.co/GRuO8Mo9iJ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/GRuO8Mo9iJ',
#          'expanded_url': 'https://lewry.com/',
#          'display_url': 'lewry.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2164,
#      'friends_count': 667,
#      'listed_count': 55,
#      'created_at': 'Wed Mar 21 21:00:17 +0000 2007',
#      'favourites_count': 3693,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 4557,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '204A87',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1586588754051227649/0MDr46N__normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1586588754051227649/0MDr46N__normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1795971/1641101965',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FAC409',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2490,
#     'favorite_count': 18778,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2490,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 03 18:29:24 +0000 2022',
#    'id': 1588236921226121219,
#    'id_str': '1588236921226121219',
#    'text': 'RT @chrisfluming: elon musk’s twitter journey is very jack skellington trying to do christmas',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'chrisfluming',
#       'name': 'Chris Fleming',
#       'id': 309912891,
#       'id_str': '309912891',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2299514943,
#     'id_str': '2299514943',
#     'name': 'Rhiannon 🌿',
#     'screen_name': 'rhiannonwillson',
#     'location': 'Wales, United Kingdom',
#     'description': 'poet, carer, sub-standard scrabble player',
#     'url': 'https://t.co/UdJFVYrkqd',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/UdJFVYrkqd',
#         'expanded_url': 'http://rhiannonwillson.co.uk',
#         'display_url': 'rhiannonwillson.co.uk',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 250,
#     'friends_count': 463,
#     'listed_count': 3,
#     'created_at': 'Thu Jan 23 15:55:52 +0000 2014',
#     'favourites_count': 13134,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1780,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1356350477659754497/gtSbKIKf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1356350477659754497/gtSbKIKf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2299514943/1612214386',
#     'profile_link_color': 'FA743E',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Nov 01 19:07:58 +0000 2022',
#     'id': 1587521848392048640,
#     'id_str': '1587521848392048640',
#     'text': 'elon musk’s twitter journey is very jack skellington trying to do christmas',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 309912891,
#      'id_str': '309912891',
#      'name': 'Chris Fleming',
#      'screen_name': 'chrisfluming',
#      'location': 'Los Angeles, CA',
#      'description': 'Comedian Albany, NY 12/15 & Boston 12/17',
#      'url': 'https://t.co/awxnN9w6D6',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/awxnN9w6D6',
#          'expanded_url': 'https://chrisflemingfleming.com/',
#          'display_url': 'chrisflemingfleming.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 184426,
#      'friends_count': 730,
#      'listed_count': 270,
#      'created_at': 'Thu Jun 02 21:49:53 +0000 2011',
#      'favourites_count': 10368,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 893,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1215819081791598592/403wpRNJ_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1215819081791598592/403wpRNJ_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/309912891/1655143305',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 8319,
#     'favorite_count': 79214,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 8319,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 03 18:29:24 +0000 2022',
#    'id': 1588236919523184641,
#    'id_str': '1588236919523184641',
#    'text': 'RT @mranewliz: Yeni bir eğitim videosuyla daha karşınızdayım🎯\n\nSon zamanlarda Elon Musk ile anlaşmasıyla gündeme gelen #Binance  borsasına;…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Binance', 'indices': [119, 127]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'mranewliz',
#       'name': 'MRanewliz',
#       'id': 1362360173382279185,
#       'id_str': '1362360173382279185',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1364331578307002374,
#     'id_str': '1364331578307002374',
#     'name': 'BarBar',
#     'screen_name': 'BarBar_19',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 314,
#     'friends_count': 295,
#     'listed_count': 3,
#     'created_at': 'Tue Feb 23 21:49:42 +0000 2021',
#     'favourites_count': 44230,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 49345,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1586113726675050501/BOH7Dhps_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1586113726675050501/BOH7Dhps_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 30 17:02:00 +0000 2022',
#     'id': 1586765373398863873,
#     'id_str': '1586765373398863873',
#     'text': 'Yeni bir eğitim videosuyla daha karşınızdayım🎯\n\nSon zamanlarda Elon Musk ile anlaşmasıyla gündeme gelen #Binance  b… https://t.co/QC8tn5QjBe',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Binance', 'indices': [104, 112]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/QC8tn5QjBe',
#        'expanded_url': 'https://twitter.com/i/web/status/1586765373398863873',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1362360173382279185,
#      'id_str': '1362360173382279185',
#      'name': 'MRanewliz',
#      'screen_name': 'mranewliz',
#      'location': '',
#      'description': 'MR analiz //#bitcoin ve #altcoin analizlerimi ve alım satımlarımı yazıyorum/ ODTÜ / Computer Engineering📈\nytd: yatırım tavsiyesi değildir😊\nmranewliz@gmail.com',
#      'url': 'https://t.co/fKHOEQ04Tx',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/fKHOEQ04Tx',
#          'expanded_url': 'https://t.me/mranewlizteam',
#          'display_url': 't.me/mranewlizteam',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 74340,
#      'friends_count': 141,
#      'listed_count': 248,
#      'created_at': 'Thu Feb 18 11:16:01 +0000 2021',
#      'favourites_count': 10543,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 6534,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1362368767632822272/9OuJw6mv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1362368767632822272/9OuJw6mv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1362360173382279185/1635765094',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 22,
#     'favorite_count': 88,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'tr'},
#    'is_quote_status': False,
#    'retweet_count': 22,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tr'},
#   {'created_at': 'Thu Nov 03 18:29:24 +0000 2022',
#    'id': 1588236918797787136,
#    'id_str': '1588236918797787136',
#    'text': 'RT @TonsTweetings: สรุปดราม่า Elon Musk กับ Twitter ล่าสุด\n\n🤑 ผู้ใช้ทั่วไปใช้ฟรีไม่เปลี่ยนแปลง\n🤴 ผู้ใช้กลุ่ม Verified account จะโดนถอด ✅ ออ…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TonsTweetings',
#       'name': 'Tonno \U0001fae0',
#       'id': 15457437,
#       'id_str': '15457437',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 702528699124420608,
#     'id_str': '702528699124420608',
#     'name': 'ปะละกออะละเกงอะละกุอะละกิ5',
#     'screen_name': 'porabcdefghijkl',
#     'location': '',
#     'description': 'อยากถูกหวย',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 47,
#     'friends_count': 220,
#     'listed_count': 0,
#     'created_at': 'Wed Feb 24 16:21:09 +0000 2016',
#     'favourites_count': 3837,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 21114,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1396887934456918016/-9cWH_7I_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1396887934456918016/-9cWH_7I_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/702528699124420608/1587751070',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Nov 03 03:34:44 +0000 2022',
#     'id': 1588011770589089793,
#     'id_str': '1588011770589089793',
#     'text': 'สรุปดราม่า Elon Musk กับ Twitter ล่าสุด\n\n🤑 ผู้ใช้ทั่วไปใช้ฟรีไม่เปลี่ยนแปลง\n🤴 ผู้ใช้กลุ่ม Verified account จะโดนถอด… https://t.co/A3aBpRYPqO',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/A3aBpRYPqO',
#        'expanded_url': 'https://twitter.com/i/web/status/1588011770589089793',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#     'source': '<a href="http://itunes.apple.com/us/app/twitter/id409789998?mt=12" rel="nofollow">Twitter for Mac</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 15457437,
#      'id_str': '15457437',
#      'name': 'Tonno \U0001fae0',
#      'screen_name': 'TonsTweetings',
#      'location': 'Work/Biz please DM',
#      'description': 'I used to build skyscrapers. Now entrepreneur + PE fund. Proud but never satisfied. Passions: tech, games, travel, fitness+nutrition. LSE/UCL/Melb. TH/EN 🚌🅿️',
#      'url': 'https://t.co/oIjlEvuwgF',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/oIjlEvuwgF',
#          'expanded_url': 'http://instagr.am/tonnosgram',
#          'display_url': 'instagr.am/tonnosgram',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 89328,
#      'friends_count': 647,
#      'listed_count': 147,
#      'created_at': 'Wed Jul 16 18:03:24 +0000 2008',
#      'favourites_count': 4511,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 162694,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FF6699',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1539516921896263681/yE13p47I_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1539516921896263681/yE13p47I_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15457437/1637669822',
#      'profile_link_color': 'ABB8C2',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': '252429',
#      'profile_text_color': '666666',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'regular',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 10032,
#     'favorite_count': 2237,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'th'},
#    'is_quote_status': False,
#    'retweet_count': 10032,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'th'},
#   {'created_at': 'Thu Nov 03 18:29:24 +0000 2022',
#    'id': 1588236918328033280,
#    'id_str': '1588236918328033280',
#    'text': 'RT @StephenKing: Kudos to Elon Musk, who has begun a revolution in how the world drives and who has incredible visionary talents. I got an…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'StephenKing',
#       'name': 'Stephen King',
#       'id': 2233154425,
#       'id_str': '2233154425',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1195909106248216577,
#     'id_str': '1195909106248216577',
#     'name': 'Nilesh Gaikwadᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠᅠ༝',
#     'screen_name': 'Bhaujanunite',
#     'location': 'Nagpur, India',
#     'description': 'We must stand on our own feet and fight as best as we can for our rights. So carry on your agitation and organize your forces. Power and prestige will come to u',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2668,
#     'friends_count': 4139,
#     'listed_count': 3,
#     'created_at': 'Sun Nov 17 03:39:03 +0000 2019',
#     'favourites_count': 216132,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 182660,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1575754526543728640/HA8LSIWJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1575754526543728640/HA8LSIWJ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1195909106248216577/1666372728',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Nov 03 00:53:38 +0000 2022',
#     'id': 1587971229595668480,
#     'id_str': '1587971229595668480',
#     'text': 'Kudos to Elon Musk, who has begun a revolution in how the world drives and who has incredible visionary talents. I… https://t.co/QdW0XyT0iR',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/QdW0XyT0iR',
#        'expanded_url': 'https://twitter.com/i/web/status/1587971229595668480',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2233154425,
#      'id_str': '2233154425',
#      'name': 'Stephen King',
#      'screen_name': 'StephenKing',
#      'location': '',
#      'description': 'Author',
#      'url': 'http://t.co/iPedKNPjre',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/iPedKNPjre',
#          'expanded_url': 'http://stephenking.com',
#          'display_url': 'stephenking.com',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6966869,
#      'friends_count': 147,
#      'listed_count': 15721,
#      'created_at': 'Fri Dec 06 15:26:35 +0000 2013',
#      'favourites_count': 40,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 7394,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000836981162/b683f7509ec792c3e481ead332940cdc_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000836981162/b683f7509ec792c3e481ead332940cdc_normal.jpeg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4421,
#     'favorite_count': 88285,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 4421,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 03 18:29:23 +0000 2022',
#    'id': 1588236914909270017,
#    'id_str': '1588236914909270017',
#    'text': 'RT @tatsunoritoku: 記事元。企業や有名人にとっては安いものだけど、認証マークが金で買えちゃうとなると、意味あるんだろうか。\n\nhttps://t.co/lQamOeioUM',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'tatsunoritoku',
#       'name': '徳重龍徳（ライター、グラビア評論家）@ホークス&ちいかわファン',
#       'id': 24877080,
#       'id_str': '24877080',
#       'indices': [3, 17]}],
#     'urls': [{'url': 'https://t.co/lQamOeioUM',
#       'expanded_url': 'https://www.theverge.com/2022/10/30/23431931/twitter-paid-verification-elon-musk-blue-monthly-subscription',
#       'display_url': 'theverge.com/2022/10/30/234…',
#       'indices': [72, 95]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 60269300,
#     'id_str': '60269300',
#     'name': 'すずな',
#     'screen_name': 'soozna',
#     'location': '京都市',
#     'description': '基本お一人様｡絶賛エレカシ,怒髪天､中村達也､志の輔,萬斎,中村屋,古田新太,奈良美智…liveに芝居に忙しい。旨酒旨飯を求めて日々彷徨う。もやしもん,大島弓子,谷地恵美子,山下和美､松田奈緒子,浦沢直樹etc漫画も好き！そして旅の見知らぬ町を彷徨うのが好き',
#     'url': 'https://t.co/V92RccoxBY',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/V92RccoxBY',
#         'expanded_url': 'http://Instagram.com/suzunanaka',
#         'display_url': 'Instagram.com/suzunanaka',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 609,
#     'friends_count': 828,
#     'listed_count': 16,
#     'created_at': 'Sun Jul 26 09:00:56 +0000 2009',
#     'favourites_count': 43689,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 285783,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFCC4D',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
# ...
#        'id_str': '1588230158460375041',
#        'indices': [121, 144],
#        'media_url': 'http://pbs.twimg.com/media/FgqG6hCX0AEDCEZ.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FgqG6hCX0AEDCEZ.jpg',
#        'url': 'https://t.co/cGazaCMZdz',
#        'display_url': 'pic.twitter.com/cGazaCMZdz',
#        'expanded_url': 'https://twitter.com/savagekizz/status/1588230168182677510/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 898, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 1242, 'h': 1660, 'resize': 'fit'},
#         'small': {'w': 509, 'h': 680, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3391854167,
#      'id_str': '3391854167',
#      'name': 'Amala Ambassador 🧩',
#      'screen_name': 'savagekizz',
#      'location': '',
#      'description': 'Your Fav Amala Tourist || iPR/Campaigns || #Obidient ✊🏾||#LFC 🏆|| RT ≠ ✍🏾 || 📥 Amalatourist@gmail.com',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 33297,
#      'friends_count': 1876,
#      'listed_count': 8,
#      'created_at': 'Tue Jul 28 11:08:35 +0000 2015',
#      'favourites_count': 5244,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 7193,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1579887482145017857/N2ePpdaA_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1579887482145017857/N2ePpdaA_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3391854167/1666010133',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 10,
#     'favorite_count': 11,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 10,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 03 18:28:59 +0000 2022',
#    'id': 1588236815064260611,
#    'id_str': '1588236815064260611',
#    'text': "RT @PuestoLoco: @CalltoActivism @AOC Oh, look! Twitter stock was delisted so it's price is unavailable. But Elon Musk used a large chunk of…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'PuestoLoco',
#       'name': 'Puesto Loco™',
#       'id': 157099071,
#       'id_str': '157099071',
#       'indices': [3, 14]},
#      {'screen_name': 'CalltoActivism',
#       'name': 'CALL TO ACTIVISM',
#       'id': 819994707061248001,
#       'id_str': '819994707061248001',
#       'indices': [16, 31]},
#      {'screen_name': 'AOC',
#       'name': 'Alexandria Ocasio-Cortez',
#       'id': 138203134,
#       'id_str': '138203134',
#       'indices': [32, 36]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1049615270283812866,
#     'id_str': '1049615270283812866',
#     'name': 'Free Your Mind And Your Ass Will Follow',
#     'screen_name': 'DavidJo55757507',
#     'location': 'United States',
#     'description': 'Trust,Loyalty,Respect. Fuck One Up & You Lose All 3.     Unknown',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 306,
#     'friends_count': 885,
#     'listed_count': 0,
#     'created_at': 'Tue Oct 09 10:59:16 +0000 2018',
#     'favourites_count': 58923,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 80852,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1059579978629693445/dTSXHx3p_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1059579978629693445/dTSXHx3p_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Nov 03 02:25:57 +0000 2022',
#     'id': 1587994459223912448,
#     'id_str': '1587994459223912448',
#     'text': "@CalltoActivism @AOC Oh, look! Twitter stock was delisted so it's price is unavailable. But Elon Musk used a large… https://t.co/bDq6GbIjtG",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'CalltoActivism',
#        'name': 'CALL TO ACTIVISM',
#        'id': 819994707061248001,
#        'id_str': '819994707061248001',
#        'indices': [0, 15]},
#       {'screen_name': 'AOC',
#        'name': 'Alexandria Ocasio-Cortez',
#        'id': 138203134,
#        'id_str': '138203134',
#        'indices': [16, 20]}],
#      'urls': [{'url': 'https://t.co/bDq6GbIjtG',
#        'expanded_url': 'https://twitter.com/i/web/status/1587994459223912448',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1587977574264803328,
#     'in_reply_to_status_id_str': '1587977574264803328',
#     'in_reply_to_user_id': 819994707061248001,
#     'in_reply_to_user_id_str': '819994707061248001',
#     'in_reply_to_screen_name': 'CalltoActivism',
#     'user': {'id': 157099071,
#      'id_str': '157099071',
#      'name': 'Puesto Loco™',
#      'screen_name': 'PuestoLoco',
#      'location': 'Florida Central West Coast',
#      'description': 'Military Anchor Baby - Mom never saw the irony in calling me a Son-of-a-Bitch. ClusterTrump madness is killing my country.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 37759,
#      'friends_count': 6718,
#      'listed_count': 406,
#      'created_at': 'Fri Jun 18 21:27:39 +0000 2010',
#      'favourites_count': 33677,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 464710,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '709397',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1220468837/MacPicMini_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1220468837/MacPicMini_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/157099071/1432662537',
#      'profile_link_color': '27659C',
#      'profile_sidebar_border_color': '86A4A6',
#      'profile_sidebar_fill_color': 'A0C5C7',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 47,
#     'favorite_count': 188,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 47,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 03 18:28:59 +0000 2022',
#    'id': 1588236814078320640,
#    'id_str': '1588236814078320640',
#    'text': 'RT @TheUSASingers: Elon Musk is a really stupid fucking name.\n\nWhat a pathetic embarrassment that clown is all the way around.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TheUSASingers',
#       'name': 'The USA Singers',
#       'id': 832616065259614209,
#       'id_str': '832616065259614209',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1100218578501095426,
#     'id_str': '1100218578501095426',
#     'name': 'USA',
#     'screen_name': 'Timothy77490700',
#     'location': 'United States',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 546,
#     'friends_count': 1631,
#     'listed_count': 1,
#     'created_at': 'Tue Feb 26 02:18:44 +0000 2019',
#     'favourites_count': 537420,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 410547,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1100218578501095426/1596597556',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Nov 03 15:55:53 +0000 2022',
#     'id': 1588198288750256131,
#     'id_str': '1588198288750256131',
#     'text': 'Elon Musk is a really stupid fucking name.\n\nWhat a pathetic embarrassment that clown is all the way around.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 832616065259614209,
#      'id_str': '832616065259614209',
#      'name': 'The USA Singers',
#      'screen_name': 'TheUSASingers',
#      'location': 'USA!!!!',
#      'description': 'We make Resistance Music. We stand with Democracy. We stand for Equality. We stand for Justice. We stand against Fascism. We stand against the GOP. 🤘🇺🇸🍊',
#      'url': 'https://t.co/YupIP6YOLa',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/YupIP6YOLa',
#          'expanded_url': 'http://theusasingers.com',
#          'display_url': 'theusasingers.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 119570,
#      'friends_count': 19757,
#      'listed_count': 222,
#      'created_at': 'Fri Feb 17 15:41:54 +0000 2017',
#      'favourites_count': 321837,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 88080,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1542301459622105091/7x10p9en_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1542301459622105091/7x10p9en_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/832616065259614209/1656527527',
#      'profile_link_color': 'FF691F',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 25,
#     'favorite_count': 105,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 25,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.127,
#   'max_id': 1588236922278842369,
#   'max_id_str': '1588236922278842369',
#   'next_results': '?max_id=1588236814078320639&q=Elon%20Musk&count=100&include_entities=1',
#   'query': 'Elon+Musk',
#   'refresh_url': '?since_id=1588236922278842369&q=Elon%20Musk&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
all_items=results['statuses']

# %%
df=pd.DataFrame(all_items)

# %%
df
# Out:
#                         created_at                   id               id_str  \
# 0   Thu Nov 03 18:29:24 +0000 2022  1588236922278842369  1588236922278842369
# 1   Thu Nov 03 18:29:24 +0000 2022  1588236921788145664  1588236921788145664
# 2   Thu Nov 03 18:29:24 +0000 2022  1588236921309904899  1588236921309904899
# 3   Thu Nov 03 18:29:24 +0000 2022  1588236921226121219  1588236921226121219
# 4   Thu Nov 03 18:29:24 +0000 2022  1588236919523184641  1588236919523184641
# ..                             ...                  ...                  ...
# 95  Thu Nov 03 18:29:00 +0000 2022  1588236821699477506  1588236821699477506
# 96  Thu Nov 03 18:29:00 +0000 2022  1588236821628014592  1588236821628014592
# 97  Thu Nov 03 18:29:00 +0000 2022  1588236820327931905  1588236820327931905
# 98  Thu Nov 03 18:28:59 +0000 2022  1588236815064260611  1588236815064260611
# 99  Thu Nov 03 18:28:59 +0000 2022  1588236814078320640  1588236814078320640
#
#                                                  text  truncated  \
# 0   RT @Julian_Epp: Looks like Twitter is changing...      False
# 1   RT @blogjam: I would like to pay tribute to my...      False
# 2   RT @blogjam: I would like to pay tribute to my...      False
# 3   RT @chrisfluming: elon musk’s twitter journey ...      False
# 4   RT @mranewliz: Yeni bir eğitim videosuyla daha...      False
# ..                                                ...        ...
# 95  He tweeted what? Here are 8 of the most bizarr...      False
# 96  @RickiRider @AdrienDupeyre @belizairenelson @J...       True
# 97  RT @savagekizz: Scenes where Buhari fails to r...      False
# 98  RT @PuestoLoco: @CalltoActivism @AOC Oh, look!...      False
# 99  RT @TheUSASingers: Elon Musk is a really stupi...      False
#
#                                              entities  \
# 0   {'hashtags': [], 'symbols': [], 'user_mentions...
# 1   {'hashtags': [], 'symbols': [], 'user_mentions...
# 2   {'hashtags': [], 'symbols': [], 'user_mentions...
# 3   {'hashtags': [], 'symbols': [], 'user_mentions...
# 4   {'hashtags': [{'text': 'Binance', 'indices': [...
# ..                                                ...
# 95  {'hashtags': [], 'symbols': [], 'user_mentions...
# 96  {'hashtags': [], 'symbols': [], 'user_mentions...
# 97  {'hashtags': [], 'symbols': [], 'user_mentions...
# 98  {'hashtags': [], 'symbols': [], 'user_mentions...
# 99  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                     extended_entities  \
# 0   {'media': [{'id': 1587530040962695175, 'id_str...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                              metadata  \
# 0   {'iso_language_code': 'en', 'result_type': 're...
# 1   {'iso_language_code': 'en', 'result_type': 're...
# 2   {'iso_language_code': 'en', 'result_type': 're...
# 3   {'iso_language_code': 'en', 'result_type': 're...
# 4   {'result_type': 'recent', 'iso_language_code':...
# ..                                                ...
# 95  {'iso_language_code': 'en', 'result_type': 're...
# 96  {'iso_language_code': 'fr', 'result_type': 're...
# 97  {'iso_language_code': 'en', 'result_type': 're...
# 98  {'iso_language_code': 'en', 'result_type': 're...
# 99  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                source  in_reply_to_status_id  \
# 0   <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 1   <a href="http://twitter.com/download/iphone" r...                    NaN
# 2   <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 3   <a href="http://twitter.com/download/iphone" r...                    NaN
# 4   <a href="http://twitter.com/download/iphone" r...                    NaN
# ..                                                ...                    ...
# 95  <a href="https://buffer.com" rel="nofollow">Bu...                    NaN
# 96  <a href="https://mobile.twitter.com" rel="nofo...           1.588229e+18
# 97  <a href="http://twitter.com/download/iphone" r...                    NaN
# 98  <a href="http://twitter.com/download/android" ...                    NaN
# 99  <a href="http://twitter.com/download/android" ...                    NaN
#
#     ... place  contributors  \
# 0   ...  None          None
# 1   ...  None          None
# 2   ...  None          None
# 3   ...  None          None
# 4   ...  None          None
# ..  ...   ...           ...
# 95  ...  None          None
# 96  ...  None          None
# 97  ...  None          None
# 98  ...  None          None
# 99  ...  None          None
#
#                                      retweeted_status is_quote_status  \
# 0   {'created_at': 'Tue Nov 01 19:40:32 +0000 2022...           False
# 1   {'created_at': 'Thu Nov 03 09:56:04 +0000 2022...           False
# 2   {'created_at': 'Thu Nov 03 09:56:04 +0000 2022...           False
# 3   {'created_at': 'Tue Nov 01 19:07:58 +0000 2022...           False
# 4   {'created_at': 'Sun Oct 30 17:02:00 +0000 2022...           False
# ..                                                ...             ...
# 95                                                NaN           False
# 96                                                NaN           False
# 97  {'created_at': 'Thu Nov 03 18:02:34 +0000 2022...           False
# 98  {'created_at': 'Thu Nov 03 02:25:57 +0000 2022...           False
# 99  {'created_at': 'Thu Nov 03 15:55:53 +0000 2022...           False
#
#    retweet_count favorite_count favorited retweeted possibly_sensitive lang
# 0          15972              0     False     False              False   en
# 1           2490              0     False     False                NaN   en
# 2           2490              0     False     False                NaN   en
# 3           8319              0     False     False                NaN   en
# 4             22              0     False     False                NaN   tr
# ..           ...            ...       ...       ...                ...  ...
# 95             0              0     False     False              False   en
# 96             0              0     False     False                NaN   fr
# 97            10              0     False     False                NaN   en
# 98            47              0     False     False                NaN   en
# 99            25              0     False     False                NaN   en
#
# [100 rows x 27 columns]

# %%
users=pd.DataFrame(d["user"] for d in results["statuses"])

# %%
users.head()
# Out:
#                     id               id_str                    name  \
# 0   805883214862675968   805883214862675968  I simply sail the ship
# 1             10648942             10648942      Jason Shiflet 🏳️‍🌈
# 2            240855035            240855035    Daibhid Ceannaideach
# 3           2299514943           2299514943              Rhiannon 🌿
# 4  1364331578307002374  1364331578307002374                  BarBar
#
#        screen_name                 location  \
# 0      CadetJamieD  England, United Kingdom
# 1  therealjshiflet               Dallas, TX
# 2         daibhidc
# 3  rhiannonwillson    Wales, United Kingdom
# 4        BarBar_19
#
#                                          description                      url  \
# 0  Enlglish, bisexual. She/her. 18+, minors dni. ...                     None
# 1  ISFP. Texan by birth. Seattleite at heart. IT ...  https://t.co/TWCpW4Mko3
# 2  Scottish skiffy geek. Big fan of Doctor Who an...                     None
# 3          poet, carer, sub-standard scrabble player  https://t.co/UdJFVYrkqd
# 4                                                                        None
#
#                                             entities  protected  \
# 0                      {'description': {'urls': []}}      False
# 1  {'url': {'urls': [{'url': 'https://t.co/TWCpW4...      False
# 2                      {'description': {'urls': []}}      False
# 3  {'url': {'urls': [{'url': 'https://t.co/UdJFVY...      False
# 4                      {'description': {'urls': []}}      False
#
#    followers_count  ...  profile_text_color  profile_use_background_image  \
# 0               62  ...              000000                         False
# 1              123  ...              333333                          True
# 2              245  ...              3D1957                          True
# 3              250  ...              333333                          True
# 4              314  ...              333333                          True
#
#   has_extended_profile  default_profile default_profile_image following  \
# 0                 True            False                 False      None
# 1                 True            False                 False      None
# 2                 True            False                 False      None
# 3                False            False                 False      None
# 4                 True             True                 False      None
#
#    follow_request_sent  notifications  translator_type withheld_in_countries
# 0                 None           None             none                    []
# 1                 None           None             none                    []
# 2                 None           None             none                    []
# 3                 None           None             none                    []
# 4                 None           None             none                    []
#
# [5 rows x 43 columns]

# %%
tdf=df.merge(users,left_index=True,right_index=True)

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 70 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   created_at_x                        100 non-null    object
#  1   id_x                                100 non-null    int64
#  2   id_str_x                            100 non-null    object
#  3   text                                100 non-null    object
#  4   truncated                           100 non-null    bool
#  5   entities_x                          100 non-null    object
#  6   extended_entities                   11 non-null     object
#  7   metadata                            100 non-null    object
#  8   source                              100 non-null    object
#  9   in_reply_to_status_id               6 non-null      float64
#  10  in_reply_to_status_id_str           6 non-null      object
#  11  in_reply_to_user_id                 6 non-null      float64
#  12  in_reply_to_user_id_str             6 non-null      object
#  13  in_reply_to_screen_name             6 non-null      object
#  14  user                                100 non-null    object
#  15  geo                                 0 non-null      object
#  16  coordinates                         0 non-null      object
#  17  place                               1 non-null      object
#  18  contributors                        0 non-null      object
#  19  retweeted_status                    81 non-null     object
#  20  is_quote_status                     100 non-null    bool
#  21  retweet_count                       100 non-null    int64
#  22  favorite_count                      100 non-null    int64
#  23  favorited                           100 non-null    bool
#  24  retweeted                           100 non-null    bool
#  25  possibly_sensitive                  22 non-null     object
#  26  lang_x                              100 non-null    object
#  27  id_y                                100 non-null    int64
#  28  id_str_y                            100 non-null    object
#  29  name                                100 non-null    object
#  30  screen_name                         100 non-null    object
#  31  location                            100 non-null    object
#  32  description                         100 non-null    object
#  33  url                                 28 non-null     object
#  34  entities_y                          100 non-null    object
#  35  protected                           100 non-null    bool
#  36  followers_count                     100 non-null    int64
#  37  friends_count                       100 non-null    int64
#  38  listed_count                        100 non-null    int64
#  39  created_at_y                        100 non-null    object
#  40  favourites_count                    100 non-null    int64
#  41  utc_offset                          0 non-null      object
#  42  time_zone                           0 non-null      object
#  43  geo_enabled                         100 non-null    bool
#  44  verified                            100 non-null    bool
#  45  statuses_count                      100 non-null    int64
#  46  lang_y                              0 non-null      object
#  47  contributors_enabled                100 non-null    bool
#  48  is_translator                       100 non-null    bool
#  49  is_translation_enabled              100 non-null    bool
#  50  profile_background_color            100 non-null    object
#  51  profile_background_image_url        53 non-null     object
#  52  profile_background_image_url_https  53 non-null     object
#  53  profile_background_tile             100 non-null    bool
#  54  profile_image_url                   100 non-null    object
#  55  profile_image_url_https             100 non-null    object
#  56  profile_banner_url                  87 non-null     object
#  57  profile_link_color                  100 non-null    object
#  58  profile_sidebar_border_color        100 non-null    object
#  59  profile_sidebar_fill_color          100 non-null    object
#  60  profile_text_color                  100 non-null    object
#  61  profile_use_background_image        100 non-null    bool
#  62  has_extended_profile                100 non-null    bool
#  63  default_profile                     100 non-null    bool
#  64  default_profile_image               100 non-null    bool
#  65  following                           0 non-null      object
#  66  follow_request_sent                 0 non-null      object
#  67  notifications                       0 non-null      object
#  68  translator_type                     100 non-null    object
#  69  withheld_in_countries               100 non-null    object
# dtypes: bool(15), float64(2), int64(9), object(44)
# memory usage: 44.6+ KB

# %%
tdf.location.value_counts().plot(kind='bar',figsize=(10,6))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 37117 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24066 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37117 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 24066 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from textblob import TextBlob

# %%
TextBlob("the best").sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=0.3)

# %%
def detect_sentiment(text):
    return TextBlob(text).sentiment.polarity

# %%
df2=tdf[["text"]]

# %%
df2.head()
# Out:
#                                                 text
# 0  RT @Julian_Epp: Looks like Twitter is changing...
# 1  RT @blogjam: I would like to pay tribute to my...
# 2  RT @blogjam: I would like to pay tribute to my...
# 3  RT @chrisfluming: elon musk’s twitter journey ...
# 4  RT @mranewliz: Yeni bir eğitim videosuyla daha...

# %%
df2["sentiment"]=df2["text"].apply(detect_sentiment)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#                                                 text  sentiment
# 0  RT @Julian_Epp: Looks like Twitter is changing...        0.5
# 1  RT @blogjam: I would like to pay tribute to my...        0.7
# 2  RT @blogjam: I would like to pay tribute to my...        0.7
# 3  RT @chrisfluming: elon musk’s twitter journey ...        0.2
# 4  RT @mranewliz: Yeni bir eğitim videosuyla daha...        0.0

# %%
df2.sentiment.value_counts()
# Out:
#  0.000000    47
#  0.700000     6
#  0.200000     5
#  0.136364     4
#  0.500000     3
#  0.087500     2
#  0.100000     2
#  0.300000     2
#  0.387500     2
#  0.214286     2
#  0.900000     2
#  0.350000     2
# -0.100000     1
#  0.416667     1
# -0.300000     1
#  0.150000     1
#  0.100000     1
#  0.450000     1
# -0.066667     1
#  0.425000     1
# -0.150000     1
# -0.241667     1
# -0.533333     1
#  0.318182     1
#  0.047222     1
#  0.358333     1
# -0.500000     1
# -0.166667     1
#  0.400000     1
# -0.400000     1
# -0.100000     1
#  0.156250     1
# -0.800000     1
# Name: sentiment, dtype: int64

# %%
df2["text"]=df2["text"].str.lower()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2["text"]=df2["text"].str.replace("[^\w\s]","")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2["text"]=df2["text"].str.replace("\d+","")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2["text"]=df2["text"].str.replace("\n"," ").replace("\r"," ")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
from wordcloud import STOPWORDS
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
def wc(data,bgcolor):
    plt.figure(figsize=(10,10))
    mask=np.array(Image.open("Elon.png"))
    wc=WordCloud(background_color=bgcolor,stopwords=STOPWORDS,mask=mask)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis("off")

# %%
wc(df2.text,'black')

# %%
#1=positive
#2 negative
#0 Neutral
def sentiment2(sent):
    if sent< -0.2:
        return 3
    elif sent>0.02:
        return 1
    else:
        return 0

# %%
df2["sent"]=df2["sentiment"].apply(sentiment2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#                                                 text  sentiment  sent
# 0  rt julian_epp looks like twitter is changing t...        0.5     1
# 1  rt blogjam i would like to pay tribute to my g...        0.7     1
# 2  rt blogjam i would like to pay tribute to my g...        0.7     1
# 3  rt chrisfluming elon musks twitter journey is ...        0.2     1
# 4  rt mranewliz yeni bir eğitim videosuyla daha k...        0.0     0

# %%
import seaborn as sns

# %%
sns.countplot(x=df2.sent);

# %%
x=df2.text
y=df2.sent

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
vect=CountVectorizer(stop_words="english")

# %%
x=vect.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=.15)

# %%
mb=MultinomialNB()

# %%
tahmin=mb.fit(x_train,y_train).predict(x_test)

# %%
accuracy_score(tahmin,y_test)
# Out:
# 0.6

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
d=DecisionTreeClassifier()

# %%
d.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tahmin2=d.predict(x_test)

# %%
accuracy_score(tahmin2,y_test)
# Out:
# 0.6
