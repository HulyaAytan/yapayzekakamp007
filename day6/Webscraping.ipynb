# %%
import pandas as pd

# %%
df=pd.read_clipboard() #internetten control c yaparak aldığımız tabloyu veriyor

# %%
df
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
df.to_csv("webdengelen.csv")

# %%
pip install beautifulSoup
# Out:
# ...
#   Using cached BeautifulSoup-3.2.2.tar.gz (32 kB)
#   Using cached BeautifulSoup-3.2.1.tar.gz (31 kB)
#   Using cached BeautifulSoup-3.2.0.tar.gz (31 kB)
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\T\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\T\\AppData\\Local\\Temp\\pip-install-w7llxrv4\\beautifulsoup_0e8fc6ecbe46465fb5ab5f272ec331c4\\setup.py'"'"'; __file__='"'"'C:\\Users\\T\\AppData\\Local\\Temp\\pip-install-w7llxrv4\\beautifulsoup_0e8fc6ecbe46465fb5ab5f272ec331c4\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\T\AppData\Local\Temp\pip-pip-egg-info-efz59xhi'
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("http://localhost:8000/index.html")

# %%
page.content
# Out:
# b'<html>\r\n    <title> Ilk Web Sayfam</title>\r\n    <meta charset="UTF-8">\r\n    <meta keywords="AI, Yapay Zeka, Data Science">\r\n    <body>\r\n        <h1>Sessiz Gemi</h1>\r\n        <p>\r\n            <pre>\r\n                Art\xc4\xb1k demir almak g\xc3\xbcn\xc3\xbc gelmi\xc5\x9fse zamandan\r\n                Me\xc3\xa7hule giden bir gemi kalkar bu limandan\r\n                Hi\xc3\xa7 yolcusu yokmu\xc5\x9f gibi al\xc4\xb1r yol\r\n                Sallanmaz o kalk\xc4\xb1\xc5\x9fta ne mendil ne de bir kol\r\n            </pre>\r\n        </p>\r\n        <table border="1" width="300">\r\n            <tr>\r\n                <td>Isim</td><td>Not</td>\r\n            </tr>\r\n            <tr>\r\n                <td>Ali</td><td>90</td>\r\n            </tr>\r\n            <tr>\r\n                <td>Veli</td><td>100</td>\r\n            </tr>\r\n        </table>\r\n        <table>\r\n            <tr>\r\n                <th>Company</th>\r\n                <th>Contact</th>\r\n        
# ...

# %%
soup= BeautifulSoup(page.content,'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <html>
# <title> Ilk Web Sayfam</title>
# <meta charset="utf-8"/>
# <meta keywords="AI, Yapay Zeka, Data Science"/>
# <body>
# <h1>Sessiz Gemi</h1>
# <p>
# <pre>
#                 Artık demir almak günü gelmişse zamandan
#                 Meçhule giden bir gemi kalkar bu limandan
#                 Hiç yolcusu yokmuş gibi alır yol
#                 Sallanmaz o kalkışta ne mendil ne de bir kol
#             </pre>
# </p>
# <table border="1" width="300">
# <tr>
# <td>Isim</td><td>Not</td>
# </tr>
# <tr>
# <td>Ali</td><td>90</td>
# </tr>
# <tr>
# <td>Veli</td><td>100</td>
# </tr>
# </table>
# <table>
# <tr>
# <th>Company</th>
# <th>Contact</th>
# <th>Country</th>
# </tr>
# <tr>
# <td>Alfreds Futterkiste</td>
# <td>Maria Anders</td>
# <td>Germany</td>
# </tr>
# <tr>
# <td>Centro comercial Moctezuma</td>
# <td>Francisco Chang</td>
# <td>Mexico</td></tr>
# </table>
# <marquee> <font color="red" size="7"> Yapay Zekayi seviyorum</font></marquee>
# ...

# %%
html=soup.find("html")

# %%
html.p.text
# Out:
# '\n\r\n                Artık demir almak günü gelmişse zamandan\r\n                Meçhule giden bir gemi kalkar bu limandan\r\n                Hiç yolcusu yokmuş gibi alır yol\r\n                Sallanmaz o kalkışta ne mendil ne de bir kol\r\n            \n'

# %%
df=pd.read_html(page.content)

# %%
df
# Out:
# [      0    1
#  0  Isim  Not
#  1   Ali   90
#  2  Veli  100,
#                        Company          Contact  Country
#  0         Alfreds Futterkiste     Maria Anders  Germany
#  1  Centro comercial Moctezuma  Francisco Chang   Mexico]

# %%
df[0]
# Out:
#       0    1
# 0  Isim  Not
# 1   Ali   90
# 2  Veli  100

# %%
df[1]
# Out:
#                       Company          Contact  Country
# 0         Alfreds Futterkiste     Maria Anders  Germany
# 1  Centro comercial Moctezuma  Francisco Chang   Mexico

# %%
html.text
# Out:
# '\n Ilk Web Sayfam\n\n\n\nSessiz Gemi\n\n\r\n                Artık demir almak günü gelmişse zamandan\r\n                Meçhule giden bir gemi kalkar bu limandan\r\n                Hiç yolcusu yokmuş gibi alır yol\r\n                Sallanmaz o kalkışta ne mendil ne de bir kol\r\n            \n\n\n\nIsimNot\n\n\nAli90\n\n\nVeli100\n\n\n\n\nCompany\nContact\nCountry\n\n\nAlfreds Futterkiste\nMaria Anders\nGermany\n\n\nCentro comercial Moctezuma\nFrancisco Chang\nMexico\n\n  Yapay Zekayi seviyorum\n  Yapay Zekayi seviyorum\n\nCNN\n\n'

# %%
p=soup.find("p")

# %%
p.text
# Out:
# '\n\r\n                Artık demir almak günü gelmişse zamandan\r\n                Meçhule giden bir gemi kalkar bu limandan\r\n                Hiç yolcusu yokmuş gibi alır yol\r\n                Sallanmaz o kalkışta ne mendil ne de bir kol\r\n            \n'

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://www.karar.com/yazarlar/zafer-acar/cinin-uzay-programi-tam-gaz-1589817")

# %%
page.content
# Out:
# b'<!doctype html>\r\n\t<html lang="tr">\r\n\t<head>\r\n\t\t<meta charset="utf-8"/>\r\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\r\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1"/>\r\n\t\t<title>\xc3\x87in\xe2\x80\x99in uzay program\xc4\xb1 tam gaz - Zafer Acar</title>\r\n\t\t<meta name="description" content="Uzay \xc3\xa7al\xc4\xb1\xc5\x9fmalar\xc4\xb1nda ne kadar ileride iseniz, bilim ve teknolojide de o kadar ilerler ve D\xc3\xbcnya\xe2\x80\x99da bilim ve teknolojinin \xc3\xb6nc\xc3\xbcs\xc3\xbc olur ve ekonomik..." />\n<link rel="canonical" href="https://www.karar.com/yazarlar/zafer-acar/cinin-uzay-programi-tam-gaz-1589817" />\n<link rel="amphtml" href="https://www.karar.com/amp/yazarlar/zafer-acar/cinin-uzay-programi-tam-gaz-1589817" />\n<meta property="og:type" content="article" />\n<meta property="og:site_name" content="KARAR" />\n<meta property="og:url" content="https://www.karar.com/yazarlar/zafer-acar/cinin-uzay-programi-tam-gaz-1589
# ...

# %%
soup= BeautifulSoup(page.content,'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="tr">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Çin’in uzay programı tam gaz - Zafer Acar</title>
# <meta content="Uzay çalışmalarında ne kadar ileride iseniz, bilim ve teknolojide de o kadar ilerler ve Dünya’da bilim ve teknolojinin öncüsü olur ve ekonomik..." name="description"/>
# <link href="https://www.karar.com/yazarlar/zafer-acar/cinin-uzay-programi-tam-gaz-1589817" rel="canonical"/>
# <link href="https://www.karar.com/amp/yazarlar/zafer-acar/cinin-uzay-programi-tam-gaz-1589817" rel="amphtml"/>
# <meta content="article" property="og:type"/>
# <meta content="KARAR" property="og:site_name"/>
# <meta content="https://www.karar.com/yazarlar/zafer-acar/cinin-uzay-programi-tam-gaz-1589817" property="og:url"/>
# <meta content="Çin’in uzay programı tam gaz - Zafer Acar" property="og:title"/>
# ...

# %%
html=soup.find("title")

# %%
html.text
# Out:
# 'Çin’in uzay programı tam gaz - Zafer Acar'

# %%
soup.find('h1',{"class":"content-title"}).text
# Out:
# 'Çin’in uzay programı tam gaz'

# %%
soup.find('article',{"class":"article-content"}).text
# Out:
# '\n\n\nUzay çalışmalarında ne kadar ileride iseniz, bilim ve teknolojide de o kadar ilerler ve Dünya’da bilim ve teknolojinin öncüsü olur ve ekonomik olarak çok ilerlersiniz. Çin geçtiğimiz hafta 3 tane askeri pilot olan astronotunu daha önce inşa etmeye başladığı uzay istasyonuna gönderdi. Çin en son insanlı uçuşunu 5 yıl önce gerçekleştirmişti. Çin’in uzay çalışmaları 1968’de başladı. 1970’lere geldiğimizde Çin uzaya uydu fırlatabilir duruma gelmişti. Ancak insanlı uçuş projesi yeterli yatırım yapılamadığı için 1980 yılında sonlandırıldı. 1992 yılında yeniden insanlı uçuş modülü üzerinde çalışan Çin, Ruslarla bir anlaşma yaparak, Soyuz uzay araçlarının teknolojisini transfer etti. Bu sayede 2003 yılında ilk insanlı uçuşunu gerçekleştirdi ve o gün bugündür uzay yarışında hızlı adımlarla ilerliyor.  Çin son 2 yılda hem Ay’a hem de Mars’a uzay aracı gönderdi. Ay’ın Dünya’dan görünmeyen tarafına ilk defa uzay aracı gönderirken, Ay’dan örnek alıp getirebilen bir ülke haline geldi. Aynı 
# ...

# %%
url="https://www.karar.com/yazarlar/zafer-acar"

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.content,'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="tr">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Zafer Acar - KARAR</title>
# <meta content="Zafer Acar tarafından KARAR için yazılan makaleler" name="description"/>
# <link href="https://www.karar.com/yazarlar/zafer-acar" rel="canonical"/>
# <meta content="website" property="og:type"/>
# <meta content="KARAR" property="og:site_name"/>
# <meta content="https://www.karar.com/yazarlar/zafer-acar" property="og:url"/>
# <meta content="Zafer Acar" property="og:title"/>
# <meta content="Zafer Acar tarafından KARAR için yazılan makaleler" property="og:description"/>
# <meta content="https://cdn.karar.com/author/75_b.jpg" property="og:image"/>
# <meta content="200" property="og:image:width"/>
# <meta content="200" property="og:image:height"/>
# <meta content="app-id=1009271502" name="apple-itunes-app"/>
# ...

# %%
linkler=soup.find_all("article",{"class":"item box-shadow"})

# %%
for i in linkler:
    print(i)
# Out:
# <article class="item box-shadow">
# <a href="/yazarlar/zafer-acar/engellilerin-umudu-yapay-zeka-1590090">
# <h3>Engellilerin umudu yapay zeka</h3>
# <p>Yapay zeka her alanda büyük değişimler ve gelişimler vaad ediyor. Almanya’da yapılan yeni bir araştırma, görme engelli vatandaşlarımızın...</p>
# </a>
# <time datetime="2021-07-19 00:23:00">19.07.2021</time>
# </article>
# <article class="item box-shadow">
# <a href="/yazarlar/zafer-acar/kuantum-yapay-zeka-1590019">
# <h3>Kuantum yapay zeka</h3>
# <p>Teknolojik gelişmeler baş döndürücü hızla ilerliyor. Önümüzdeki 30 yıl yapay zeka yılı olacak derken, kuantum bilgisayarlar büyük bir ilerleme...</p>
# </a>
# <time datetime="2021-07-12 00:06:00">12.07.2021</time>
# </article>
# <article class="item box-shadow">
# <a href="/yazarlar/zafer-acar/astronot-001-1589950">
# <h3>Astronot 001</h3>
# <p>Uzay çalışmaları ve uçuşları küçüklüğümden beri hep ilgimi çekmiştir. Özellikle son 12 yıldır nerede bir astronomi etkinliği olursa,...</p>
# ...

# %%
yazilar=[]
basliklar=[]
for link in linkler:
    yazilinki="https://www.karar.com"+link.a.get("href")
    #print(yazilinki) 
    page=requests.get(yazilinki)
    soup= BeautifulSoup(page.content,'html.parser')
    baslik=soup.find('h1',{"class":"content-title"}).text
    yazi=soup.find('article',{"class":"article-content"}).text
    yazilar.append(yazi)
    basliklar.append(baslik)

# %%
df=pd.DataFrame(columns=["konu","makale"])

# %%
df["konu"]=basliklar
df["makale"]=yazilar

# %%
df.head()
# Out:
#                             konu  \
# 0  Engellilerin umudu yapay zeka
# 1             Kuantum yapay zeka
# 2                   Astronot 001
# 3   Çin’in uzay programı tam gaz
# 4    Yapay zeka ile çip tasarımı
#
#                                               makale
# 0  \n\n\nYapay zeka her alanda büyük değişimler v...
# 1  \n\n\nTeknolojik gelişmeler baş döndürücü hızl...
# 2  \n\n\nUzay çalışmaları ve uçuşları küçüklüğümd...
# 3  \n\n\nUzay çalışmalarında ne kadar ileride ise...
# 4  \n\n\nGeçtiğimiz hafta Google, bilgisayar çipl...

# %%
df['makale'][0]
# Out:
# '\n\n\nYapay zeka her alanda büyük değişimler ve gelişimler vaad ediyor. Almanya’da yapılan yeni bir araştırma, görme engelli vatandaşlarımızın gerçek dünyada gezinmelerine yardımcı olmak için GPU ile çalışan, taşınabilir bir sistem geliştirdi. Daha önce de yapay zeka ile görme engelli vatandaşlarımızın belirlenen ve işaretlenen yollarda rahatça koşmaları sağlanmıştı. Bu kez sırtınızda taşıyacağınız bir laptop ve gözlüğünüze monte edebileceğiniz bir kamera ile normal insan gibi gezmek, görmek, karşıdan gelen arkadaşlarınızı tanımak ve selam vermek artık problem olmaktan çıkacak.Ülkemizde maalesef fiziksel ve zihinsel özürlü çok sayıda vatandaşımız var. Bunların en zoru muhtemelen görme ve işitme. Tekerlekli sandalyeye mahkum olan veya bir tekerlekli sandalye bile bulamayan çok sayıda engelli vatandaşımız da var. Devletimiz engelli vatandaşlarımıza bir miktar sahip çıksa da, özürlü bir bireye sahip olan aileler, bu meseleyi sanki utanç verici bir şeymiş gibi düşünüyor ve çocuklarını t
# ...

# %%
url="http://datatables.net/"

# %%
page=requests.get(url)

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_html(page.content)

# %%
df=df[0]

# %%
df
# Out:
#                    Name                       Position         Office  Age  \
# 0           Tiger Nixon               System Architect      Edinburgh   61
# 1       Garrett Winters                     Accountant          Tokyo   63
# 2            Ashton Cox        Junior Technical Author  San Francisco   66
# 3          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 4            Airi Satou                     Accountant          Tokyo   33
# 5    Brielle Williamson         Integration Specialist       New York   61
# 6       Herrod Chandler                Sales Assistant  San Francisco   59
# 7        Rhona Davidson         Integration Specialist          Tokyo   55
# 8         Colleen Hurst           Javascript Developer  San Francisco   39
# 9           Sonya Frost              Software Engineer      Edinburgh   23
# 10          Jena Gaines                 Office Manager         London   30
# ...
