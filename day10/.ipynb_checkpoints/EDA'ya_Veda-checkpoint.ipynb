# %%
pip install pandas_profiling
# Out:
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27096 sha256=dde05ff97425055d96f61fb76eb4c5cb031bc0ef41ea577fc9991d3ce6278fd4
#   Stored in directory: c:\users\t\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
from pandas_profiling import ProfileReport

# %%
df=pd.read_csv("cars.csv")

# %%
a=ProfileReport(df)

# %%
a.to_file("EDA.html")
