# %%
pip install twython
# Out:
# Requirement already satisfied: twython in c:\users\t\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in c:\users\t\anaconda3\lib\site-packages (from twython) (1.3.1)
# Requirement already satisfied: requests>=2.1.0 in c:\users\t\anaconda3\lib\site-packages (from twython) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\t\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\t\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\t\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\t\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\t\anaconda3\lib\site-packages (from requests-oauthlib>=0.4.0->twython) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from twython import Twython

# %%
import pandas as pd

# %%
CONSUMER_KEY = '0pJRCT1emkOcrtxHl7lMN4N5A'
CONSUMER_SECRET = 'IS4Gxcx1aQ1c5Hyei5PSePLS37IcVmYBT8Qt1t4IOxmLIxJD42'

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET)

# %%
results=twitter.search(q="trump",count=100)

# %%
results
# Out:
# {'statuses': [{'created_at': 'Sun Oct 30 07:39:41 +0000 2022',
#    'id': 1586623862606790656,
#    'id_str': '1586623862606790656',
#    'text': 'RT @jonathanalter: Here’s what Pelosi said when Rep. Scalise was shot at a cong. ballgame: “On days like today, there are no Democrats or R…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'jonathanalter',
#       'name': 'Jonathan Alter',
#       'id': 21844854,
#       'id_str': '21844854',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1582438270553784320,
#     'id_str': '1582438270553784320',
#     'name': 'Frenchtuck',
#     'screen_name': 'Frenchtuck1',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 10,
#     'friends_count': 135,
#     'listed_count': 0,
#     'created_at': 'Tue Oct 18 18:28:03 +0000 2022',
#     'favourites_count': 1568,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 826,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 19:36:58 +0000 2022',
#     'id': 1586441982771355649,
#     'id_str': '1586441982771355649',
#     'text': 'Here’s what Pelosi said when Rep. Scalise was shot at a cong. ballgame: “On days like today, there are no Democrats… https://t.co/Q7m5ChQz6R',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Q7m5ChQz6R',
#        'expanded_url': 'https://twitter.com/i/web/status/1586441982771355649',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 21844854,
#      'id_str': '21844854',
#      'name': 'Jonathan Alter',
#      'screen_name': 'jonathanalter',
#      'location': '',
#      'description': 'Husband, father; author (of books on FDR, Obama and Carter); MSNBC analyst; documentary filmmaker; columnist; SiriusXm co-host; founder, https://t.co/EzVqSYgl7o',
#      'url': 'https://t.co/gfc5wBPCcn',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/gfc5wBPCcn',
#          'expanded_url': 'http://jonathanalter.com',
#          'display_url': 'jonathanalter.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/EzVqSYgl7o',
#          'expanded_url': 'http://oldgoats.substack.com',
#          'display_url': 'oldgoats.substack.com',
#          'indices': [137, 160]}]}},
#      'protected': False,
#      'followers_count': 119570,
#      'friends_count': 824,
#      'listed_count': 2213,
#      'created_at': 'Wed Feb 25 07:15:20 +0000 2009',
#      'favourites_count': 144,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 29858,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '9AE4E8',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1391815162009735182/rADotZGI_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1391815162009735182/rADotZGI_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21844854/1620669776',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDFFCC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1066,
#     'favorite_count': 3726,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1066,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:39:41 +0000 2022',
#    'id': 1586623862070206464,
#    'id_str': '1586623862070206464',
#    'text': 'RT @kylegriffin1: Pres. Obama says Republican politicians seem obsessed with two things: "owning the libs" and "getting Donald Trump\'s appr…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'kylegriffin1',
#       'name': 'Kyle Griffin',
#       'id': 32871086,
#       'id_str': '32871086',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 773748515956748288,
#     'id_str': '773748515956748288',
#     'name': 'Maryanne paulson',
#     'screen_name': 'Maryannepaulso3',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 158,
#     'friends_count': 266,
#     'listed_count': 7,
#     'created_at': 'Thu Sep 08 05:03:16 +0000 2016',
#     'favourites_count': 69,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 218433,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 18:30:06 +0000 2022',
#     'id': 1586425158285201408,
#     'id_str': '1586425158285201408',
#     'text': 'Pres. Obama says Republican politicians seem obsessed with two things: "owning the libs" and "getting Donald Trump\'… https://t.co/i74Ucnnho5',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/i74Ucnnho5',
#        'expanded_url': 'https://twitter.com/i/web/status/1586425158285201408',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 32871086,
#      'id_str': '32871086',
#      'name': 'Kyle Griffin',
#      'screen_name': 'kylegriffin1',
#      'location': 'Los Angeles, CA',
#      'description': "Executive Producer. MSNBC's @AymanMSNBC and @MehdiHasanShow. Opinions mine. Do not congratulate.",
#      'url': 'https://t.co/1vRL91g006',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/1vRL91g006',
#          'expanded_url': 'https://www.instagram.com/griffinkyle/',
#          'display_url': 'instagram.com/griffinkyle/',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1393362,
#      'friends_count': 785,
#      'listed_count': 9819,
#      'created_at': 'Sat Apr 18 12:45:48 +0000 2009',
#      'favourites_count': 36009,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 83537,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/961462238732275712/omWV1cZs_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/961462238732275712/omWV1cZs_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/32871086/1455243585',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3225,
#     'favorite_count': 11926,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3225,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:39:41 +0000 2022',
#    'id': 1586623861059211269,
#    'id_str': '1586623861059211269',
#    'text': '@LouDobbs @YahooNews Let them do it, they are risking being boycotted by all those IN THE WORLD that support Trump… https://t.co/RjO92yqQvt',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'LouDobbs',
#       'name': 'Lou Dobbs',
#       'id': 26487169,
#       'id_str': '26487169',
#       'indices': [0, 9]},
#      {'screen_name': 'YahooNews',
#       'name': 'Yahoo News',
#       'id': 7309052,
#       'id_str': '7309052',
#       'indices': [10, 20]}],
#     'urls': [{'url': 'https://t.co/RjO92yqQvt',
#       'expanded_url': 'https://twitter.com/i/web/status/1586623861059211269',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1586332399214170112,
#    'in_reply_to_status_id_str': '1586332399214170112',
#    'in_reply_to_user_id': 26487169,
#    'in_reply_to_user_id_str': '26487169',
#    'in_reply_to_screen_name': 'LouDobbs',
#    'user': {'id': 303147205,
#     'id_str': '303147205',
#     'name': 'Daisy Woo',
#     'screen_name': 'DaisyWoo3',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1,
#     'friends_count': 16,
#     'listed_count': 0,
#     'created_at': 'Sun May 22 11:19:58 +0000 2011',
#     'favourites_count': 298,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 295,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:39:39 +0000 2022',
#    'id': 1586623854855835648,
#    'id_str': '1586623854855835648',
#    'text': 'RT @laderechadiario: 🇧🇷🇺🇸 | Donald Trump brinda su apoyo a la reelección de Jair Bolsonaro de cara a la Segunda Vuelta: "Brasileños, tienen…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'laderechadiario',
#       'name': 'La Derecha Diario',
#       'id': 1169664359628509184,
#       'id_str': '1169664359628509184',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2976714046,
#     'id_str': '2976714046',
#     'name': 'ANGELES ROLDAN',
#     'screen_name': 'RoldanAlcai',
#     'location': 'España 💚🇪🇸',
#     'description': 'Chef privada y sumiller de vinos de Jerez. Amante de la buena mesa, las buenas costumbres y del flamenco. Artista y adicta al Tai chi. TU CUERPO ES TU TEMPLO.',
#     'url': 'https://t.co/kVpuXFJAui',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/kVpuXFJAui',
#         'expanded_url': 'http://www.vipfoodandsherry.com',
#         'display_url': 'vipfoodandsherry.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2791,
#     'friends_count': 5002,
#     'listed_count': 8,
#     'created_at': 'Tue Jan 13 16:14:39 +0000 2015',
#     'favourites_count': 58262,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 19918,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1539126258906324992/516wyVkZ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1539126258906324992/516wyVkZ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2976714046/1655791636',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 30 02:55:45 +0000 2022',
#     'id': 1586552408267755520,
#     'id_str': '1586552408267755520',
#     'text': '🇧🇷🇺🇸 | Donald Trump brinda su apoyo a la reelección de Jair Bolsonaro de cara a la Segunda Vuelta: "Brasileños, tie… https://t.co/YpgePrqqRz',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/YpgePrqqRz',
#        'expanded_url': 'https://twitter.com/i/web/status/1586552408267755520',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1169664359628509184,
#      'id_str': '1169664359628509184',
#      'name': 'La Derecha Diario',
#      'screen_name': 'laderechadiario',
#      'location': 'Argentina',
#      'description': '📰 | Noticias. Te contamos lo que ningún otro medio te cuenta. Encuestas @pulsopopular_ | Deportes @lddeportes | Versión Brasil @jornaldireitaOK',
#      'url': 'https://t.co/N2c72UwTYl',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/N2c72UwTYl',
#          'expanded_url': 'https://derechadiario.com.ar/',
#          'display_url': 'derechadiario.com.ar',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 199801,
#      'friends_count': 137,
#      'listed_count': 509,
#      'created_at': 'Thu Sep 05 17:32:23 +0000 2019',
#      'favourites_count': 2085,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 13845,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1546600176562966528/P-xnE-yd_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1546600176562966528/P-xnE-yd_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1169664359628509184/1612425089',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 550,
#     'favorite_count': 2042,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'es'},
#    'is_quote_status': False,
#    'retweet_count': 550,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'es'},
#   {'created_at': 'Sun Oct 30 07:39:39 +0000 2022',
#    'id': 1586623853878337536,
#    'id_str': '1586623853878337536',
#    'text': 'RT @Alphawolf_1_: Oh my god! LOOK AT THIS! \n\nYou cant miss it! \n\nSales of the revolutionary new #memetoken start in a few days \n\nA huge tea…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'memetoken', 'indices': [96, 106]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Alphawolf_1_',
#       'name': 'Crypto Alpha ✪',
#       'id': 1428688987259080704,
#       'id_str': '1428688987259080704',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1500459083064741891,
#     'id_str': '1500459083064741891',
#     'name': 'el 💤 will see sebongs \U0001faf6🏼',
#     'screen_name': 'oxiw1ns',
#     'location': 'ph— she/her; 18+ ',
#     'description': "pakigising na lang ako pag nanalo na 'ko ✰ hunter acc (i often change my un)  turn off my rts, thank u :)",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 64,
#     'friends_count': 3709,
#     'listed_count': 0,
#     'created_at': 'Sun Mar 06 13:11:45 +0000 2022',
#     'favourites_count': 12736,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 27597,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1580453606041395200/JX8_HiEB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1580453606041395200/JX8_HiEB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1500459083064741891/1663637757',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 30 04:11:58 +0000 2022',
#     'id': 1586571590678073345,
#     'id_str': '1586571590678073345',
#     'text': 'Oh my god! LOOK AT THIS! \n\nYou cant miss it! \n\nSales of the revolutionary new #memetoken start in a few days \n\nA hu… https://t.co/Proud6ypRB',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'memetoken', 'indices': [78, 88]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Proud6ypRB',
#        'expanded_url': 'https://twitter.com/i/web/status/1586571590678073345',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1428688987259080704,
#      'id_str': '1428688987259080704',
#      'name': 'Crypto Alpha ✪',
#      'screen_name': 'Alphawolf_1_',
#      'location': 'Worldwide 🌎',
#      'description': 'NFT & Crypto Projects Promoter | DevOps/Web3 Developer | Power Plant Operations Lead Engineer | Journalist | Reward Proofs 🏆: #CryptoAlphaVouch',
#      'url': 'https://t.co/oyH9ewaZ9l',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/oyH9ewaZ9l',
#          'expanded_url': 'https://alphawolf-1.net/',
#          'display_url': 'alphawolf-1.net',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 256127,
#      'friends_count': 145,
#      'listed_count': 2099,
#      'created_at': 'Fri Aug 20 12:03:01 +0000 2021',
#      'favourites_count': 942,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 7728,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1585214617160192004/5khEz8a2_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1585214617160192004/5khEz8a2_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1428688987259080704/1666596017',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7326,
#     'favorite_count': 7111,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7326,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:39:39 +0000 2022',
#    'id': 1586623853261950976,
#    'id_str': '1586623853261950976',
#    'text': 'RT @jairbolsonaro: - Meu obrigado a Donald Trump pelo apoio! Sinto orgulho por ver que nosso trabalho por um Brasil mais seguro e mais livr…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'jairbolsonaro',
#       'name': 'Jair M. Bolsonaro 2️⃣2️⃣',
#       'id': 128372940,
#       'id_str': '128372940',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1153512931960741889,
#     'id_str': '1153512931960741889',
#     'name': 'Ribeiro V.',
#     'screen_name': 'Valdire01567572',
#     'location': 'Cartigliano, Veneto',
#     'description': 'Brasileira da Itália!\nQue luta é quer um país melhor para todos!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 51,
#     'friends_count': 123,
#     'listed_count': 0,
#     'created_at': 'Tue Jul 23 03:51:28 +0000 2019',
#     'favourites_count': 4221,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2588,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1455301021782183944/BeyWf00l_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1455301021782183944/BeyWf00l_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 30 02:09:53 +0000 2022',
#     'id': 1586540865618591744,
#     'id_str': '1586540865618591744',
#     'text': '- Meu obrigado a Donald Trump pelo apoio! Sinto orgulho por ver que nosso trabalho por um Brasil mais seguro e mais… https://t.co/6JVsM2kMQY',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/6JVsM2kMQY',
#        'expanded_url': 'https://twitter.com/i/web/status/1586540865618591744',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 128372940,
#      'id_str': '128372940',
#      'name': 'Jair M. Bolsonaro 2️⃣2️⃣',
#      'screen_name': 'jairbolsonaro',
#      'location': 'Brasília, Brasil',
#      'description': 'Capitão Paraquedista do Exército Brasileiro. Presidente da República Federativa do Brasil. Candidato à reeleição com o número 2⃣2⃣.',
#      'url': 'https://t.co/DzletgH0tv',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/DzletgH0tv',
#          'expanded_url': 'https://t.me/jairbolsonarobrasil',
#          'display_url': 't.me/jairbolsonarob…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 9626285,
#      'friends_count': 518,
#      'listed_count': 8606,
#      'created_at': 'Wed Mar 31 23:13:44 +0000 2010',
#      'favourites_count': 5979,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 15358,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '175C17',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1559734581942800385/qtN3jE9H_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1559734581942800385/qtN3jE9H_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/128372940/1663337696',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'A4E37F',
#      'profile_text_color': '1414FF',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 15176,
#     'favorite_count': 66897,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'pt'},
#    'is_quote_status': False,
#    'retweet_count': 15176,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Sun Oct 30 07:39:37 +0000 2022',
#    'id': 1586623845749985282,
#    'id_str': '1586623845749985282',
#    'text': 'RT @nathaliejacoby1: What’s the first thing you’d do if you found out Trump was going to jail?',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'nathaliejacoby1',
#       'name': 'Nathalie Jacoby',
#       'id': 1280478731874848769,
#       'id_str': '1280478731874848769',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1580127922433687552,
#     'id_str': '1580127922433687552',
#     'name': 'Robert Shabbag',
#     'screen_name': 'RobertShabbag',
#     'location': 'Los Alamitos, CA',
#     'description': 'Life himself is a teacher🧑\u200d🏫 the more you live the more you learn 🤬',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 47,
#     'friends_count': 95,
#     'listed_count': 0,
#     'created_at': 'Wed Oct 12 09:27:21 +0000 2022',
#     'favourites_count': 518,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6653,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1580129998446411778/M0nFj0fl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1580129998446411778/M0nFj0fl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1580127922433687552/1665567372',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 19:52:24 +0000 2022',
#     'id': 1586445870618189824,
#     'id_str': '1586445870618189824',
#     'text': 'What’s the first thing you’d do if you found out Trump was going to jail?',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1280478731874848769,
#      'id_str': '1280478731874848769',
#      'name': 'Nathalie Jacoby',
#      'screen_name': 'nathaliejacoby1',
#      'location': 'USA',
#      'description': 'Democrat•Loves animals•Kindness matters most of all♥️Press ‘Super Follow’ if you want to learn how to gain followers fast and build a strong account like mine!',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 240062,
#      'friends_count': 60061,
#      'listed_count': 263,
#      'created_at': 'Tue Jul 07 12:28:59 +0000 2020',
#      'favourites_count': 179519,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 57776,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1545779273784561673/zQ48Sd4b_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1545779273784561673/zQ48Sd4b_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1280478731874848769/1603487333',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 204,
#     'favorite_count': 1606,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 204,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:39:37 +0000 2022',
#    'id': 1586623844953083904,
#    'id_str': '1586623844953083904',
#    'text': 'RT @MoeedNj: Gharida Ji, Unfortunately "Indian Card" is dead in Pakistani politics! This lemon has been squeezed by all of us so many times…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MoeedNj',
#       'name': 'Moeed Pirzada',
#       'id': 577459091,
#       'id_str': '577459091',
#       'indices': [3, 11]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4015994891,
#     'id_str': '4015994891',
#     'name': 'Shahzad Niazi🌐',
#     'screen_name': 'ShahzadNiazi13',
#     'location': 'Mianwali, Pakistan',
#     'description': '\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200fمشہور ہونے کی خواہش انسان کو کہیں کا نہیں چھوڑتی، گمنامی کی زندگی نبیوں،ولیوں کا شیوہ ہے،مشہور ہونےسے زیادہ اچھے اخلاق پر توجہ دیں',
#     'url': 'https://t.co/KtmFwqSaAl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KtmFwqSaAl',
#         'expanded_url': 'http://Instagram.com/Shahzad4883',
#         'display_url': 'Instagram.com/Shahzad4883',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 951,
#     'friends_count': 1550,
#     'listed_count': 5,
#     'created_at': 'Thu Oct 22 09:45:31 +0000 2015',
#     'favourites_count': 115348,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 61304,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1550057138621407232/Yy6JyOIP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1550057138621407232/Yy6JyOIP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4015994891/1507008337',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 00:52:46 +0000 2022',
#     'id': 1586159068682813440,
#     'id_str': '1586159068682813440',
#     'text': 'Gharida Ji, Unfortunately "Indian Card" is dead in Pakistani politics! This lemon has been squeezed by all of us so… https://t.co/AAdI4znUh6',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/AAdI4znUh6',
#        'expanded_url': 'https://twitter.com/i/web/status/1586159068682813440',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 577459091,
#      'id_str': '577459091',
#      'name': 'Moeed Pirzada',
#      'screen_name': 'MoeedNj',
#      'location': 'Islamabad',
#      'description': 'CEO & Editor Global Village Space;TV Anchor at 92 News, prominent Columnist & Blogger',
#      'url': 'https://t.co/2n16VZiecv',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/2n16VZiecv',
#          'expanded_url': 'http://www.moeedpirzada.pk',
#          'display_url': 'moeedpirzada.pk',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2844524,
#      'friends_count': 923,
#      'listed_count': 1539,
#      'created_at': 'Fri May 11 21:05:29 +0000 2012',
#      'favourites_count': 3816,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 54562,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/2218850823/Dr._Moeed_Pirzada_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2218850823/Dr._Moeed_Pirzada_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/577459091/1464525814',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1585977258719821824,
#     'quoted_status_id_str': '1585977258719821824',
#     'quoted_status': {'created_at': 'Fri Oct 28 12:50:19 +0000 2022',
#      'id': 1585977258719821824,
#      'id_str': '1585977258719821824',
#      'text': '“عمران بمقابلہ پاکستان” عمران خان کی پارٹی کے پاکستان آرمی پر الزامات۔۔ یہ ہیں بھارت کے میڈیا کی ہیڈلائنز۔۔ \nعمران… https://t.co/OfbROzC6aQ',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/OfbROzC6aQ',
#         'expanded_url': 'https://twitter.com/i/web/status/1585977258719821824',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [116, 139]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 405667557,
#       'id_str': '405667557',
#       'name': 'Gharidah Farooqi',
#       'screen_name': 'GFarooqi',
#       'location': 'Heart-Pakistan Soul-Kashmir',
#       'description': "I AM ~ Steel Magnolia. Millennial. Feminist. Activist. Journalist since 2003. Program 'G For Gharidah' on News One - Monday to Thursday. Tweets only personal.",
#       'url': 'https://t.co/Yb2MHmXtqf',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/Yb2MHmXtqf',
#           'expanded_url': 'https://www.instagram.com/gfarooqi/',
#           'display_url': 'instagram.com/gfarooqi/',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 1680644,
#       'friends_count': 2668,
#       'listed_count': 972,
#       'created_at': 'Sat Nov 05 16:41:28 +0000 2011',
#       'favourites_count': 24827,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': True,
#       'statuses_count': 41663,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': '7DF0DB',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1267760820051677189/P5M5PAUo_normal.jpg',
# ...
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 30 04:11:58 +0000 2022',
#     'id': 1586571590678073345,
#     'id_str': '1586571590678073345',
#     'text': 'Oh my god! LOOK AT THIS! \n\nYou cant miss it! \n\nSales of the revolutionary new #memetoken start in a few days \n\nA hu… https://t.co/Proud6ypRB',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'memetoken', 'indices': [78, 88]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Proud6ypRB',
#        'expanded_url': 'https://twitter.com/i/web/status/1586571590678073345',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1428688987259080704,
#      'id_str': '1428688987259080704',
#      'name': 'Crypto Alpha ✪',
#      'screen_name': 'Alphawolf_1_',
#      'location': 'Worldwide 🌎',
#      'description': 'NFT & Crypto Projects Promoter | DevOps/Web3 Developer | Power Plant Operations Lead Engineer | Journalist | Reward Proofs 🏆: #CryptoAlphaVouch',
#      'url': 'https://t.co/oyH9ewaZ9l',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/oyH9ewaZ9l',
#          'expanded_url': 'https://alphawolf-1.net/',
#          'display_url': 'alphawolf-1.net',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 256127,
#      'friends_count': 145,
#      'listed_count': 2099,
#      'created_at': 'Fri Aug 20 12:03:01 +0000 2021',
#      'favourites_count': 942,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 7728,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1585214617160192004/5khEz8a2_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1585214617160192004/5khEz8a2_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1428688987259080704/1666596017',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7326,
#     'favorite_count': 7111,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7326,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:39:05 +0000 2022',
#    'id': 1586623712123576322,
#    'id_str': '1586623712123576322',
#    'text': "RT @JohnFugelsang: Trump will ignore this subpoena like it's his kids' birthdays.",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'JohnFugelsang',
#       'name': 'John Fugelsang',
#       'id': 33276161,
#       'id_str': '33276161',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1453270633,
#     'id_str': '1453270633',
#     'name': 'Bev',
#     'screen_name': 'HillBeverlyhill',
#     'location': 'Texas ',
#     'description': 'Graduate TCU',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 36356,
#     'friends_count': 34098,
#     'listed_count': 61,
#     'created_at': 'Fri May 24 04:58:26 +0000 2013',
#     'favourites_count': 287502,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 404758,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1019803342862610432/m2wpN-9a_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1019803342862610432/m2wpN-9a_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Oct 21 21:44:26 +0000 2022',
#     'id': 1583574961490313217,
#     'id_str': '1583574961490313217',
#     'text': "Trump will ignore this subpoena like it's his kids' birthdays.",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 33276161,
#      'id_str': '33276161',
#      'name': 'John Fugelsang',
#      'screen_name': 'JohnFugelsang',
#      'location': 'NYC, LA & The Beautiful South',
#      'description': 'comedian-actor-broadcaster & recovering cynic * SiriusXM #127 M-F * https://t.co/kbXv0rVdUC * Our new podcast:https://t.co/VKOQMKRCMH',
#      'url': 'https://t.co/BYU6Oo37Pk',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/BYU6Oo37Pk',
#          'expanded_url': 'http://johnfugelsang.com',
#          'display_url': 'johnfugelsang.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/kbXv0rVdUC',
#          'expanded_url': 'http://instagram.com/johnfugelsang/',
#          'display_url': 'instagram.com/johnfugelsang/',
#          'indices': [68, 91]},
#         {'url': 'https://t.co/VKOQMKRCMH',
#          'expanded_url': 'http://apple.co/38mTKuO',
#          'display_url': 'apple.co/38mTKuO',
#          'indices': [110, 133]}]}},
#      'protected': False,
#      'followers_count': 497110,
#      'friends_count': 19922,
#      'listed_count': 6401,
#      'created_at': 'Sun Apr 19 18:45:06 +0000 2009',
#      'favourites_count': 118845,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 89010,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1555413259771158529/oWsw4eah_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1555413259771158529/oWsw4eah_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/33276161/1410187033',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 493,
#     'favorite_count': 3794,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 493,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:39:05 +0000 2022',
#    'id': 1586623709875511299,
#    'id_str': '1586623709875511299',
#    'text': 'RT @harryelsocio: Don Musk, una cosita ahora que hay libertad,\n- Twitter es Corea del Norte\n- A Trump le robaron las elecciones \n- Si tiene…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'harryelsocio',
#       'name': 'Alégrame el día',
#       'id': 804071774182903808,
#       'id_str': '804071774182903808',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1323229518,
#     'id_str': '1323229518',
#     'name': 'kimi 🇪🇸',
#     'screen_name': 'Jjgrne',
#     'location': '',
#     'description': 'Sevilla',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 262,
#     'friends_count': 576,
#     'listed_count': 0,
#     'created_at': 'Tue Apr 02 20:46:32 +0000 2013',
#     'favourites_count': 54373,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 53228,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'BADFCD',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3490668300/d02eaa334e6733b6bf8ef69f95be24e7_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3490668300/d02eaa334e6733b6bf8ef69f95be24e7_normal.jpeg',
#     'profile_link_color': 'FF0000',
#     'profile_sidebar_border_color': 'F2E195',
#     'profile_sidebar_fill_color': 'FFF7CC',
#     'profile_text_color': '0C3E53',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 21:12:43 +0000 2022',
#     'id': 1586466081513754624,
#     'id_str': '1586466081513754624',
#     'text': 'Don Musk, una cosita ahora que hay libertad,\n- Twitter es Corea del Norte\n- A Trump le robaron las elecciones \n- Si… https://t.co/7v9aOcO2TM',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/7v9aOcO2TM',
#        'expanded_url': 'https://twitter.com/i/web/status/1586466081513754624',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 804071774182903808,
#      'id_str': '804071774182903808',
#      'name': 'Alégrame el día',
#      'screen_name': 'harryelsocio',
#      'location': ' En Parler: @harryelsocio',
#      'description': 'Viajero. “I am not the same, having seen the moon shine on the other side of the world.”',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 76841,
#      'friends_count': 1503,
#      'listed_count': 184,
#      'created_at': 'Wed Nov 30 21:17:04 +0000 2016',
#      'favourites_count': 151148,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 8188,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1279078687057510401/pneT9irY_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1279078687057510401/pneT9irY_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/804071774182903808/1497283273',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 768,
#     'favorite_count': 2588,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'es'},
#    'is_quote_status': False,
#    'retweet_count': 768,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'es'}],
#  'search_metadata': {'completed_in': 0.132,
#   'max_id': 1586623862606790656,
#   'max_id_str': '1586623862606790656',
#   'next_results': '?max_id=1586623709875511298&q=trump&count=100&include_entities=1',
#   'query': 'trump',
#   'refresh_url': '?since_id=1586623862606790656&q=trump&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
all_items=results['statuses']

# %%
df=pd.DataFrame(all_items)

# %%
df
# Out:
#                         created_at                   id               id_str  \
# 0   Sun Oct 30 07:39:41 +0000 2022  1586623862606790656  1586623862606790656
# 1   Sun Oct 30 07:39:41 +0000 2022  1586623862070206464  1586623862070206464
# 2   Sun Oct 30 07:39:41 +0000 2022  1586623861059211269  1586623861059211269
# 3   Sun Oct 30 07:39:39 +0000 2022  1586623854855835648  1586623854855835648
# 4   Sun Oct 30 07:39:39 +0000 2022  1586623853878337536  1586623853878337536
# ..                             ...                  ...                  ...
# 84  Sun Oct 30 07:39:06 +0000 2022  1586623714422128641  1586623714422128641
# 85  Sun Oct 30 07:39:05 +0000 2022  1586623712786354176  1586623712786354176
# 86  Sun Oct 30 07:39:05 +0000 2022  1586623712316469250  1586623712316469250
# 87  Sun Oct 30 07:39:05 +0000 2022  1586623712123576322  1586623712123576322
# 88  Sun Oct 30 07:39:05 +0000 2022  1586623709875511299  1586623709875511299
#
#                                                  text  truncated  \
# 0   RT @jonathanalter: Here’s what Pelosi said whe...      False
# 1   RT @kylegriffin1: Pres. Obama says Republican ...      False
# 2   @LouDobbs @YahooNews Let them do it, they are ...       True
# 3   RT @laderechadiario: 🇧🇷🇺🇸 | Donald Trump brind...      False
# 4   RT @Alphawolf_1_: Oh my god! LOOK AT THIS! \n\...      False
# ..                                                ...        ...
# 84  RT @KtyCaty: @UnionPierre Potus est réactivé i...      False
# 85  RT @LiamMiller33: Historian describes Donald T...      False
# 86  RT @Alphawolf_1_: Oh my god! LOOK AT THIS! \n\...      False
# 87  RT @JohnFugelsang: Trump will ignore this subp...      False
# 88  RT @harryelsocio: Don Musk, una cosita ahora q...      False
#
#                                              entities  \
# 0   {'hashtags': [], 'symbols': [], 'user_mentions...
# 1   {'hashtags': [], 'symbols': [], 'user_mentions...
# 2   {'hashtags': [], 'symbols': [], 'user_mentions...
# 3   {'hashtags': [], 'symbols': [], 'user_mentions...
# 4   {'hashtags': [{'text': 'memetoken', 'indices':...
# ..                                                ...
# 84  {'hashtags': [], 'symbols': [], 'user_mentions...
# 85  {'hashtags': [], 'symbols': [], 'user_mentions...
# 86  {'hashtags': [{'text': 'memetoken', 'indices':...
# 87  {'hashtags': [], 'symbols': [], 'user_mentions...
# 88  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                              metadata  \
# 0   {'iso_language_code': 'en', 'result_type': 're...
# 1   {'iso_language_code': 'en', 'result_type': 're...
# 2   {'iso_language_code': 'en', 'result_type': 're...
# 3   {'iso_language_code': 'es', 'result_type': 're...
# 4   {'iso_language_code': 'en', 'result_type': 're...
# ..                                                ...
# 84  {'iso_language_code': 'fr', 'result_type': 're...
# 85  {'iso_language_code': 'en', 'result_type': 're...
# 86  {'iso_language_code': 'en', 'result_type': 're...
# 87  {'iso_language_code': 'en', 'result_type': 're...
# 88  {'iso_language_code': 'es', 'result_type': 're...
#
#                                                source  in_reply_to_status_id  \
# 0   <a href="http://twitter.com/download/iphone" r...                    NaN
# 1   <a href="http://twitter.com/download/iphone" r...                    NaN
# 2   <a href="https://mobile.twitter.com" rel="nofo...           1.586332e+18
# 3   <a href="http://twitter.com/download/iphone" r...                    NaN
# 4   <a href="http://twitter.com/download/android" ...                    NaN
# ..                                                ...                    ...
# 84  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 85  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 86  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 87  <a href="http://twitter.com/download/iphone" r...                    NaN
# 88  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    in_reply_to_status_id_str  ...  retweet_count favorite_count favorited  \
# 0                       None  ...           1066              0     False
# 1                       None  ...           3225              0     False
# 2        1586332399214170112  ...              0              0     False
# 3                       None  ...            550              0     False
# 4                       None  ...           7326              0     False
# ..                       ...  ...            ...            ...       ...
# 84                      None  ...              1              0     False
# 85                      None  ...             12              0     False
# 86                      None  ...           7326              0     False
# 87                      None  ...            493              0     False
# 88                      None  ...            768              0     False
#
#    retweeted lang quoted_status_id quoted_status_id_str possibly_sensitive  \
# 0      False   en              NaN                  NaN                NaN
# 1      False   en              NaN                  NaN                NaN
# 2      False   en              NaN                  NaN                NaN
# 3      False   es              NaN                  NaN                NaN
# 4      False   en              NaN                  NaN                NaN
# ..       ...  ...              ...                  ...                ...
# 84     False   fr              NaN                  NaN                NaN
# 85     False   en              NaN                  NaN              False
# 86     False   en              NaN                  NaN                NaN
# 87     False   en              NaN                  NaN                NaN
# 88     False   es              NaN                  NaN                NaN
#
#    quoted_status  extended_entities
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            NaN                NaN
# ..           ...                ...
# 84           NaN                NaN
# 85           NaN                NaN
# 86           NaN                NaN
# 87           NaN                NaN
# 88           NaN                NaN
#
# [89 rows x 30 columns]

# %%
users=pd.DataFrame(d["user"] for d in results["statuses"])

# %%
users.head()
# Out:
#                     id               id_str                      name  \
# 0  1582438270553784320  1582438270553784320                Frenchtuck
# 1   773748515956748288   773748515956748288          Maryanne paulson
# 2            303147205            303147205                 Daisy Woo
# 3           2976714046           2976714046            ANGELES ROLDAN
# 4  1500459083064741891  1500459083064741891  el 💤 will see sebongs 🫶🏼
#
#        screen_name           location  \
# 0      Frenchtuck1
# 1  Maryannepaulso3
# 2        DaisyWoo3
# 3      RoldanAlcai         España 💚🇪🇸
# 4          oxiw1ns  ph— she/her; 18+
#
#                                          description                      url  \
# 0                                                                        None
# 1                                                                        None
# 2                                                                        None
# 3  Chef privada y sumiller de vinos de Jerez. Ama...  https://t.co/kVpuXFJAui
# 4  pakigising na lang ako pag nanalo na 'ko ✰ hun...                     None
#
#                                             entities  protected  \
# 0                      {'description': {'urls': []}}      False
# 1                      {'description': {'urls': []}}      False
# 2                      {'description': {'urls': []}}      False
# 3  {'url': {'urls': [{'url': 'https://t.co/kVpuXF...      False
# 4                      {'description': {'urls': []}}      False
#
#    followers_count  ...  profile_use_background_image  has_extended_profile  \
# 0               10  ...                          True                  True
# 1              158  ...                          True                 False
# 2                1  ...                          True                 False
# 3             2791  ...                          True                 False
# 4               64  ...                          True                  True
#
#   default_profile  default_profile_image following follow_request_sent  \
# 0            True                   True      None                None
# 1            True                   True      None                None
# 2            True                   True      None                None
# 3            True                  False      None                None
# 4            True                  False      None                None
#
#    notifications  translator_type  withheld_in_countries  \
# 0           None             none                     []
# 1           None             none                     []
# 2           None             none                     []
# 3           None             none                     []
# 4           None             none                     []
#
#                                   profile_banner_url
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://pbs.twimg.com/profile_banners/29767140...
# 4  https://pbs.twimg.com/profile_banners/15004590...
#
# [5 rows x 43 columns]

# %%
tdf=df.merge(users,left_index=True,right_index=True)

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 73 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   created_at_x                        89 non-null     object
#  1   id_x                                89 non-null     int64
#  2   id_str_x                            89 non-null     object
#  3   text                                89 non-null     object
#  4   truncated                           89 non-null     bool
#  5   entities_x                          89 non-null     object
#  6   metadata                            89 non-null     object
#  7   source                              89 non-null     object
#  8   in_reply_to_status_id               20 non-null     float64
#  9   in_reply_to_status_id_str           20 non-null     object
#  10  in_reply_to_user_id                 20 non-null     float64
#  11  in_reply_to_user_id_str             20 non-null     object
#  12  in_reply_to_screen_name             20 non-null     object
#  13  user                                89 non-null     object
#  14  geo                                 0 non-null      object
#  15  coordinates                         0 non-null      object
#  16  place                               0 non-null      object
#  17  contributors                        0 non-null      object
#  18  retweeted_status                    63 non-null     object
#  19  is_quote_status                     89 non-null     bool
#  20  retweet_count                       89 non-null     int64
#  21  favorite_count                      89 non-null     int64
#  22  favorited                           89 non-null     bool
#  23  retweeted                           89 non-null     bool
#  24  lang_x                              89 non-null     object
#  25  quoted_status_id                    4 non-null      float64
#  26  quoted_status_id_str                4 non-null      object
#  27  possibly_sensitive                  10 non-null     object
#  28  quoted_status                       2 non-null      object
#  29  extended_entities                   1 non-null      object
#  30  id_y                                89 non-null     int64
#  31  id_str_y                            89 non-null     object
#  32  name                                89 non-null     object
#  33  screen_name                         89 non-null     object
#  34  location                            89 non-null     object
#  35  description                         89 non-null     object
#  36  url                                 9 non-null      object
#  37  entities_y                          89 non-null     object
#  38  protected                           89 non-null     bool
#  39  followers_count                     89 non-null     int64
#  40  friends_count                       89 non-null     int64
#  41  listed_count                        89 non-null     int64
#  42  created_at_y                        89 non-null     object
#  43  favourites_count                    89 non-null     int64
#  44  utc_offset                          0 non-null      object
#  45  time_zone                           0 non-null      object
#  46  geo_enabled                         89 non-null     bool
#  47  verified                            89 non-null     bool
#  48  statuses_count                      89 non-null     int64
#  49  lang_y                              0 non-null      object
#  50  contributors_enabled                89 non-null     bool
#  51  is_translator                       89 non-null     bool
#  52  is_translation_enabled              89 non-null     bool
#  53  profile_background_color            89 non-null     object
#  54  profile_background_image_url        34 non-null     object
#  55  profile_background_image_url_https  34 non-null     object
#  56  profile_background_tile             89 non-null     bool
#  57  profile_image_url                   89 non-null     object
#  58  profile_image_url_https             89 non-null     object
#  59  profile_link_color                  89 non-null     object
#  60  profile_sidebar_border_color        89 non-null     object
#  61  profile_sidebar_fill_color          89 non-null     object
#  62  profile_text_color                  89 non-null     object
#  63  profile_use_background_image        89 non-null     bool
#  64  has_extended_profile                89 non-null     bool
#  65  default_profile                     89 non-null     bool
#  66  default_profile_image               89 non-null     bool
#  67  following                           0 non-null      object
#  68  follow_request_sent                 0 non-null      object
#  69  notifications                       0 non-null      object
#  70  translator_type                     89 non-null     object
#  71  withheld_in_countries               89 non-null     object
#  72  profile_banner_url                  56 non-null     object
# dtypes: bool(15), float64(3), int64(9), object(46)
# memory usage: 41.8+ KB

# %%
tdf.location.value_counts().plot(kind='bar',figsize=(10,6))
# Out:
# <AxesSubplot:>
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128154 (\N{GREEN HEART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127466 (\N{REGIONAL INDICATOR SYMBOL LETTER E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127480 (\N{REGIONAL INDICATOR SYMBOL LETTER S}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127470 (\N{REGIONAL INDICATOR SYMBOL LETTER I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127465 (\N{REGIONAL INDICATOR SYMBOL LETTER D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Sentiment Analysis

# %%
from textblob import TextBlob

# %%
TextBlob("Love").polarity
# Out:
# 0.5

# %%
TextBlob("hate").polarity
# Out:
# -0.8

# %%
TextBlob("the best").polarity
# Out:
# 1.0

# %%
TextBlob("the best").sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=0.3)

# %%
def detect_sentiment(text):
    return TextBlob(text).sentiment.polarity

# %%
df2=tdf[["text"]]

# %%
df2.head()
# Out:
#                                                 text
# 0  RT @jonathanalter: Here’s what Pelosi said whe...
# 1  RT @kylegriffin1: Pres. Obama says Republican ...
# 2  @LouDobbs @YahooNews Let them do it, they are ...
# 3  RT @laderechadiario: 🇧🇷🇺🇸 | Donald Trump brind...
# 4  RT @Alphawolf_1_: Oh my god! LOOK AT THIS! \n\...

# %%
df2["sentiment"]=df2["text"].apply(detect_sentiment)
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_4424\1909004749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["sentiment"]=df2["text"].apply(detect_sentiment)

# %%
df2.head()
# Out:
#                                                 text  sentiment
# 0  RT @jonathanalter: Here’s what Pelosi said whe...   0.000000
# 1  RT @kylegriffin1: Pres. Obama says Republican ...  -0.500000
# 2  @LouDobbs @YahooNews Let them do it, they are ...   0.000000
# 3  RT @laderechadiario: 🇧🇷🇺🇸 | Donald Trump brind...   0.000000
# 4  RT @Alphawolf_1_: Oh my god! LOOK AT THIS! \n\...   0.112121

# %%
df2.sentiment.value_counts()
# Out:
#  0.000000    49
#  0.112121    10
# -0.500000     4
#  0.500000     3
#  0.016667     2
# -0.600000     2
# -0.041667     1
#  0.200000     1
# -0.208333     1
#  0.258333     1
#  0.350000     1
# -0.166667     1
#  0.250000     1
#  0.700000     1
#  0.850000     1
# -0.350000     1
# -0.156250     1
#  0.050000     1
#  0.200000     1
#  0.400000     1
# -0.100000     1
#  0.045833     1
# -0.083333     1
#  0.075000     1
#  0.375000     1
# Name: sentiment, dtype: int64

# %%
df2["text"]=df2["text"].str.lower()
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_4424\1934567259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.lower()

# %%
df2["text"]=df2["text"].str.replace("[^\w\s]","")
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_4424\265055035.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2["text"]=df2["text"].str.replace("[^\w\s]","")
# C:\Users\T\AppData\Local\Temp\ipykernel_4424\265055035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.replace("[^\w\s]","")

# %%
df2["text"]=df2["text"].str.replace("\d+","")
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_4424\1924162430.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2["text"]=df2["text"].str.replace("\d+","")
# C:\Users\T\AppData\Local\Temp\ipykernel_4424\1924162430.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.replace("\d+","")

# %%
df2["text"]=df2["text"].str.replace("\n"," ").replace("\r"," ")
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_4424\892400714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.replace("\n"," ").replace("\r"," ")

# %%
from wordcloud import STOPWORDS
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
def wc(data,bgcolor):
    plt.figure(figsize=(10,10))
    mask=np.array(Image.open("trump.png"))
    wc=WordCloud(background_color=bgcolor,stopwords=STOPWORDS,mask=mask)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis("off")

# %%
wc(df2.text,'white')

# %%
#1=positive
#2 negative
#0 Neutral
def sentiment2(sent):
    if sent< -0.2:
        return 3
    elif sent>0.02:
        return 1
    else:
        return 0

# %%
df2["sent"]=df2["sentiment"].apply(sentiment2)
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_4424\3383788003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["sent"]=df2["sentiment"].apply(sentiment2)

# %%
df2.head()
# Out:
#                                                 text  sentiment  sent
# 0  rt jonathanalter heres what pelosi said when r...   0.000000     0
# 1  rt kylegriffin pres obama says republican poli...  -0.500000     3
# 2  loudobbs yahoonews let them do it they are ris...   0.000000     0
# 3  rt laderechadiario   donald trump brinda su ap...   0.000000     0
# 4  rt alphawolf__ oh my god look at this   you ca...   0.112121     1

# %%
import seaborn as sns

# %%
sns.countplot(x=df2.sent);

# %%
x=df2.text
y=df2.sent

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
vect=CountVectorizer(stop_words="english")

# %%
x=vect.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=.15)

# %%
mb=MultinomialNB()

# %%
tahmin=mb.fit(x_train,y_train).predict(x_test)

# %%
accuracy_score(tahmin,y_test) # verimiz 100 satirlik
# Out:
# 0.6428571428571429

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
d=DecisionTreeClassifier()

# %%
d.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tahmin2=d.predict(x_test)

# %%
accuracy_score(tahmin2,y_test)
# Out:
# 0.6428571428571429
