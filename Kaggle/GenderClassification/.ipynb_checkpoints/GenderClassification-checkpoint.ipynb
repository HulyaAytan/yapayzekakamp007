# %% [markdown]
# ##About the Dataset
# This dataset contains 7 features and a label column.
#
# long_hair - This column contains 0's and 1's where 1 is "long hair" and 0 is "not long hair".
# forehead_width_cm - This column is in CM's. This is the width of the forehead.
# forehead_height_cm - This is the height of the forehead and it's in Cm's.
# nose_wide - This column contains 0's and 1's where 1 is "wide nose" and 0 is "not wide nose".
# nose_long - This column contains 0's and 1's where 1 is "Long nose" and 0 is "not long nose".
# lips_thin - This column contains 0's and 1's where 1 represents the "thin lips" while 0 is "Not thin lips".
# distance_nose_to_lip_long - This column contains 0's and 1's where 1 represents the "long distance between nose and lips" while 0 is "short distance between nose and lips".
#
# gender - This is either "Male" or "Female".

# %% [markdown]
# ## Import Libraries and Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",100)

#Classification
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix,precision_score,recall_score,f1_score

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.preprocessing import normalize,scale

# %%
df=pd.read_csv('gender_classification_v7.csv')
df.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
df.shape
# Out:
# (5001, 8)

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %%
df.isnull().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
df.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  5001.000000        5001.000000         5001.000000  5001.000000
# mean      0.869626          13.181484            5.946311     0.493901
# std       0.336748           1.107128            0.541268     0.500013
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.200000            5.500000     0.000000
# 50%       1.000000          13.100000            5.900000     0.000000
# 75%       1.000000          14.000000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  5001.000000  5001.000000                5001.000000
# mean      0.507898     0.493101                   0.498900
# std       0.499988     0.500002                   0.500049
# min       0.000000     0.000000                   0.000000
# 25%       0.000000     0.000000                   0.000000
# 50%       1.000000     0.000000                   0.000000
# 75%       1.000000     1.000000                   1.000000
# max       1.000000     1.000000                   1.000000

# %%
df.corr()
# Out:
#                            long_hair  forehead_width_cm  forehead_height_cm  \
# long_hair                   1.000000          -0.006530           -0.017233
# forehead_width_cm          -0.006530           1.000000            0.088596
# forehead_height_cm         -0.017233           0.088596            1.000000
# nose_wide                   0.001216           0.251648            0.211655
# nose_long                   0.014432           0.257368            0.194120
# lips_thin                   0.011287           0.258564            0.205441
# distance_nose_to_lip_long  -0.025794           0.251328            0.215292
#
#                            nose_wide  nose_long  lips_thin  \
# long_hair                   0.001216   0.014432   0.011287
# forehead_width_cm           0.251648   0.257368   0.258564
# forehead_height_cm          0.211655   0.194120   0.205441
# nose_wide                   1.000000   0.565192   0.557615
# nose_long                   0.565192   1.000000   0.561229
# lips_thin                   0.557615   0.561229   1.000000
# distance_nose_to_lip_long   0.569303   0.559794   0.565312
#
#                            distance_nose_to_lip_long
# long_hair                                  -0.025794
# forehead_width_cm                           0.251328
# forehead_height_cm                          0.215292
# nose_wide                                   0.569303
# nose_long                                   0.559794
# lips_thin                                   0.565312
# distance_nose_to_lip_long                   1.000000

# %%
# Correlation of the columns shown in a heatmap
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)

# %%
sns.countplot(df['gender'])

# %%
plt.figure(figsize = (15,15))
sns.pairplot(df, hue="gender");

# %%
df['gender']=df['gender'].map({'Female':1,'Male':0})

# %%
df.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1       0
# 1          1                          0       1
# 2          1                          1       0
# 3          1                          1       0
# 4          0                          0       1

# %% [markdown]
# ## Apply ML Algorithms

# %%
# Function to call all Classification Algorithms
def classification_funct(dataset,column_to_be_studied):
    #importing Classification libraries
    from sklearn.naive_bayes import GaussianNB
    from sklearn.naive_bayes import BernoulliNB
    from sklearn.svm import SVC
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.linear_model import LogisticRegression
    from xgboost import XGBClassifier
    
    from sklearn.model_selection import train_test_split
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    
    from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
    from sklearn.metrics import confusion_matrix,classification_report
       
    # assign x and y
    dataset=dataset[dataset[column_to_be_studied].notnull()]
    x,y=dataset.drop(column_to_be_studied,axis=1),dataset[[column_to_be_studied]]    

    # Scale the dataset
    scaler.fit(x)
    x = scaler.transform(x)
    # split data in train and test
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
    
    # create an instance of each classification algorithm
    g=GaussianNB()
    b=BernoulliNB()
    KN=KNeighborsClassifier()
    SVC=SVC() 
    D=DecisionTreeClassifier()
    R=RandomForestClassifier()
    Log=LogisticRegression()
    XGB=XGBClassifier()
    
    algos=[g,b,KN,SVC,D,R,Log,XGB]
    algo_names=['GaussianNB','BernoulliNB','KNeighborsClassifier','SVC','DecisionTreeClassifier','RandomForestClassifier','LogisticRegression','XGBClassifier']
   
    accuracy_scored=[]
    precision_scored=[]
    recall_scored=[]
    f1_scored=[]
    
    for item in algos:
        item.fit(x_train,y_train)
        item.predict(x_test)
        accuracy_scored.append(accuracy_score(y_test,item.predict(x_test)))
        precision_scored.append(precision_score(y_test,item.predict(x_test)))
        recall_scored.append(recall_score(y_test,item.predict(x_test)))
        f1_scored.append(f1_score(y_test,item.predict(x_test)))
    
    # create dataframe with results
    result=pd.DataFrame(columns=['f1_score','recall_score','precision_score','accuracy_score'],index=algo_names)
    result['f1_score']=f1_scored
    result['recall_score']=recall_scored
    result['precision_score']=precision_scored
    result['accuracy_score']=accuracy_scored
    return result.sort_values('accuracy_score',ascending=False)

# %%
classification_funct(df,"gender")
# Out:
#                         f1_score  recall_score  precision_score  \
# XGBClassifier           0.968750      0.988048         0.950192
# SVC                     0.967615      0.982072         0.953578
# GaussianNB              0.964356      0.970120         0.958661
# BernoulliNB             0.963257      0.966135         0.960396
# RandomForestClassifier  0.963330      0.968127         0.958580
# LogisticRegression      0.961348      0.966135         0.956607
# KNeighborsClassifier    0.959764      0.974104         0.945841
# DecisionTreeClassifier  0.954365      0.958167         0.950593
#
#                         accuracy_score
# XGBClassifier                 0.968032
# SVC                           0.967033
# GaussianNB                    0.964036
# BernoulliNB                   0.963037
# RandomForestClassifier        0.963037
# LogisticRegression            0.961039
# KNeighborsClassifier          0.959041
# DecisionTreeClassifier        0.954046

# %% [markdown]
# ## Deep Learning

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(512,activation='relu'))
model.add(Dense(512,activation='relu'))
model.add(Dense(512,activation='relu'))
model.add(Dense(512,activation='relu'))
model.add(Dense(512,activation='relu'))
model.add(Dense(512,activation='relu'))
model.add(Dense(512,activation='relu'))
model.add(Dense(1,activation='sigmoid')) # sigmoid for classification

# %%
model.compile(loss='binary_crossentropy',optimizer="adam",metrics=["accuracy"])

# %%
x,y=df.drop("gender",axis=1),df[["gender"]]

# %%
model.fit(x,y,epochs=100,batch_size=50,verbose=1)
# Out:
# Epoch 1/100
# 101/101 [==============================] - 5s 6ms/step - loss: 0.2485 - accuracy: 0.8856
# Epoch 2/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0993 - accuracy: 0.9538
# Epoch 3/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0969 - accuracy: 0.9534
# Epoch 4/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.1016 - accuracy: 0.9538
# Epoch 5/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.1121 - accuracy: 0.9518
# Epoch 6/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.1011 - accuracy: 0.9542
# Epoch 7/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0983 - accuracy: 0.9546
# Epoch 8/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0956 - accuracy: 0.9560
# Epoch 9/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0964 - accuracy: 0.9592
# Epoch 10/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0926 - accuracy: 0.9558
# Epoch 11/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0971 - accuracy: 0.9550
# Epoch 12/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0986 - accuracy: 0.9562
# Epoch 13/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0945 - accuracy: 0.9560
# Epoch 14/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0928 - accuracy: 0.9564
# Epoch 15/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0931 - accuracy: 0.9566
# Epoch 16/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0882 - accuracy: 0.9568
# Epoch 17/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0905 - accuracy: 0.9572
# Epoch 18/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0891 - accuracy: 0.9568
# Epoch 19/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0923 - accuracy: 0.9574
# Epoch 20/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0947 - accuracy: 0.9578
# Epoch 21/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0911 - accuracy: 0.9560
# Epoch 22/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0899 - accuracy: 0.9568
# Epoch 23/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0956 - accuracy: 0.9592
# Epoch 24/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0915 - accuracy: 0.9574
# Epoch 25/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0887 - accuracy: 0.9558
# Epoch 26/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0944 - accuracy: 0.9588
# Epoch 27/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0895 - accuracy: 0.9576
# Epoch 28/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0858 - accuracy: 0.9576
# Epoch 29/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0860 - accuracy: 0.9590
# Epoch 30/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.1208 - accuracy: 0.9486
# Epoch 31/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0893 - accuracy: 0.9562
# Epoch 32/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0906 - accuracy: 0.9576
# Epoch 33/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0854 - accuracy: 0.9596
# Epoch 34/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0886 - accuracy: 0.9618
# Epoch 35/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0862 - accuracy: 0.9610
# Epoch 36/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0847 - accuracy: 0.9632
# Epoch 37/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0880 - accuracy: 0.9610
# Epoch 38/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9646
# Epoch 39/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 0.9624
# Epoch 40/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0840 - accuracy: 0.9648
# Epoch 41/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0821 - accuracy: 0.9646
# Epoch 42/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0864 - accuracy: 0.9636
# Epoch 43/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0821 - accuracy: 0.9582
# Epoch 44/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0824 - accuracy: 0.9624
# Epoch 45/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0907 - accuracy: 0.9578
# Epoch 46/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0858 - accuracy: 0.9604
# Epoch 47/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.9606
# Epoch 48/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.1342 - accuracy: 0.9532
# Epoch 49/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9612
# Epoch 50/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0821 - accuracy: 0.9628
# Epoch 51/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9580
# Epoch 52/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0856 - accuracy: 0.9644
# Epoch 53/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0816 - accuracy: 0.9628
# Epoch 54/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9646
# Epoch 55/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0821 - accuracy: 0.9618
# Epoch 56/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.9620
# Epoch 57/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0839 - accuracy: 0.9624
# Epoch 58/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9630
# Epoch 59/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0812 - accuracy: 0.9646
# Epoch 60/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0813 - accuracy: 0.9640
# Epoch 61/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0827 - accuracy: 0.9602
# Epoch 62/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.1064 - accuracy: 0.9526
# Epoch 63/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0932 - accuracy: 0.9590
# Epoch 64/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0926 - accuracy: 0.9616
# Epoch 65/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.9630
# Epoch 66/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0808 - accuracy: 0.9630
# Epoch 67/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0808 - accuracy: 0.9634
# Epoch 68/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9648
# Epoch 69/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9656
# Epoch 70/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0787 - accuracy: 0.9670
# Epoch 71/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0797 - accuracy: 0.9666
# Epoch 72/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 0.9650
# Epoch 73/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0773 - accuracy: 0.9666
# Epoch 74/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 0.9650
# Epoch 75/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 0.9662
# Epoch 76/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9678
# Epoch 77/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0791 - accuracy: 0.9648
# Epoch 78/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.1482 - accuracy: 0.9264
# Epoch 79/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0829 - accuracy: 0.9636
# Epoch 80/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 0.9656
# Epoch 81/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0794 - accuracy: 0.9658
# Epoch 82/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0904 - accuracy: 0.9586
# Epoch 83/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.9622
# Epoch 84/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 0.9622
# Epoch 85/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0787 - accuracy: 0.9656
# Epoch 86/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0785 - accuracy: 0.9646
# Epoch 87/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0803 - accuracy: 0.9640
# Epoch 88/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0783 - accuracy: 0.9666
# Epoch 89/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.9664
# Epoch 90/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0772 - accuracy: 0.9674
# Epoch 91/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0756 - accuracy: 0.9672
# Epoch 92/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0773 - accuracy: 0.9656
# Epoch 93/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.9646
# Epoch 94/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0771 - accuracy: 0.9674
# Epoch 95/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0779 - accuracy: 0.9682
# Epoch 96/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0760 - accuracy: 0.9666
# Epoch 97/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0794 - accuracy: 0.9688
# Epoch 98/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0771 - accuracy: 0.9670
# Epoch 99/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0786 - accuracy: 0.9664
# Epoch 100/100
# 101/101 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9664

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               4096
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  dense_5 (Dense)             (None, 512)               262656
#
#  dense_6 (Dense)             (None, 512)               262656
#
#  dense_7 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1,580,545
# Trainable params: 1,580,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
scores=model.evaluate(x,y)
# Out:
# 157/157 [==============================] - 1s 2ms/step - loss: 0.0703 - accuracy: 0.9718
