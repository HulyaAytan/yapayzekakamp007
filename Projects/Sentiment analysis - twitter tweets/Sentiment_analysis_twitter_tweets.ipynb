# %%
pip install twython
# Out:
# Requirement already satisfied: twython in c:\users\t\anaconda3\lib\site-packages (3.9.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests-oauthlib>=0.4.0 in c:\users\t\anaconda3\lib\site-packages (from twython) (1.3.1)
# Requirement already satisfied: requests>=2.1.0 in c:\users\t\anaconda3\lib\site-packages (from twython) (2.27.1)
#
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\t\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\t\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\t\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\t\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\t\anaconda3\lib\site-packages (from requests-oauthlib>=0.4.0->twython) (3.2.2)

# %%
from twython import Twython

# %%
import pandas as pd

# %%
CONSUMER_KEY = '0pJRCT1emkOcrtxHl7lMN4N5A'
CONSUMER_SECRET = 'IS4Gxcx1aQ1c5Hyei5PSePLS37IcVmYBT8Qt1t4IOxmLIxJD42'

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET)

# %%
results=twitter.search(q="Elon Musk",count=100)

# %%
results
# Out:
# {'statuses': [{'created_at': 'Fri Nov 04 21:45:29 +0000 2022',
#    'id': 1588648653081792513,
#    'id_str': '1588648653081792513',
#    'text': 'RT @MattNegrin: Elon Musk is 72 hours away from going on Joe Rogan’s podcast to defend antisemitism as essential free speech while Rogan go…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MattNegrin',
#       'name': 'Matt Negrin, HOST OF HARDBALL AT 7PM ON MSNBC',
#       'id': 15751676,
#       'id_str': '15751676',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 15617390,
#     'id_str': '15617390',
#     'name': 'Navesink',
#     'screen_name': 'Navesink',
#     'location': 'iPhone: 40.416885,-74.036148',
#     'description': 'Sam Posten - Software Engineer, Photographer, Teacher, Vol. Fireman, Tech Nut, Opinionated Curmudgeon, early adopter, gamer, privacy advocate.',
#     'url': 'https://t.co/eFBP9jFWxn',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/eFBP9jFWxn',
#         'expanded_url': 'http://www.navesink.net',
#         'display_url': 'navesink.net',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 819,
#     'friends_count': 4520,
#     'listed_count': 60,
#     'created_at': 'Sun Jul 27 04:09:50 +0000 2008',
#     'favourites_count': 33162,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 34984,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1481361515118796812/GRwO8OXz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1481361515118796812/GRwO8OXz_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15617390/1398196822',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 04 16:27:20 +0000 2022',
#     'id': 1588568588361035776,
#     'id_str': '1588568588361035776',
#     'text': 'Elon Musk is 72 hours away from going on Joe Rogan’s podcast to defend antisemitism as essential free speech while… https://t.co/BfEl3g3Lmw',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/BfEl3g3Lmw',
#        'expanded_url': 'https://twitter.com/i/web/status/1588568588361035776',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 15751676,
#      'id_str': '15751676',
#      'name': 'Matt Negrin, HOST OF HARDBALL AT 7PM ON MSNBC',
#      'screen_name': 'MattNegrin',
#      'location': 'New York',
#      'description': 'Blocked by @MeetThePress; mysteriously unblocked by @MeetThePress; former "Trump never answered the Hezbollah question" guy. Host of @hardball at 7pm on @MSNBC.',
#      'url': 'https://t.co/UVXCQpFUc8',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/UVXCQpFUc8',
#          'expanded_url': 'http://dailyshow.com/book',
#          'display_url': 'dailyshow.com/book',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 75106,
#      'friends_count': 3302,
#      'listed_count': 884,
#      'created_at': 'Wed Aug 06 16:11:47 +0000 2008',
#      'favourites_count': 33425,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 64541,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/825787279750856704/UlcPhlh7_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/825787279750856704/UlcPhlh7_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15751676/1633355748',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 244,
#     'favorite_count': 1963,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 244,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 04 21:45:29 +0000 2022',
#    'id': 1588648653010395142,
#    'id_str': '1588648653010395142',
#    'text': 'RT @gevnesis: atropelaria bolsonaristas e o elon musk por um docinho agora',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'gevnesis',
#       'name': 'nathalia',
#       'id': 1491526068884361219,
#       'id_str': '1491526068884361219',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1469983438585409537,
#     'id_str': '1469983438585409537',
#     'name': 'Luis Felipe Fonseca Da Costa',
#     'screen_name': 'LuisFel19833407',
#     'location': 'Belém,Pará',
#     'description': '🦸🏻\u200d♂️🌎Para o Alto e Avante/Up,Up And Away✝️🇧🇷',
#     'url': 'https://t.co/xFIyTPevqF',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/xFIyTPevqF',
#         'expanded_url': 'http://www.zvitor.com',
#         'display_url': 'zvitor.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2493,
#     'friends_count': 4988,
#     'listed_count': 0,
#     'created_at': 'Sun Dec 12 10:52:58 +0000 2021',
#     'favourites_count': 73945,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 60814,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1469983612011491334/RVx2iMeJ_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1469983612011491334/RVx2iMeJ_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1469983438585409537/1642936323',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 04 21:37:06 +0000 2022',
#     'id': 1588646543342866433,
#     'id_str': '1588646543342866433',
#     'text': 'atropelaria bolsonaristas e o elon musk por um docinho agora',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1491526068884361219,
#      'id_str': '1491526068884361219',
#      'name': 'nathalia',
#      'screen_name': 'gevnesis',
#      'location': 'marcela, pietra.',
#      'description': '',
#      'url': 'https://t.co/Y11zVybfaX',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Y11zVybfaX',
#          'expanded_url': 'https://boxd.it/4V8s9',
#          'display_url': 'boxd.it/4V8s9',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 109,
#      'friends_count': 98,
#      'listed_count': 0,
#      'created_at': 'Wed Feb 09 21:35:12 +0000 2022',
#      'favourites_count': 2319,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 4109,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1587989278168170496/PlqvOy6F_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1587989278168170496/PlqvOy6F_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'pt'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Fri Nov 04 21:45:28 +0000 2022',
#    'id': 1588648650770874368,
#    'id_str': '1588648650770874368',
#    'text': 'RT @parismarx: Elon Musk is literally going to burn this website to the ground because extreme right-wing posters keep egging him on and he…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'parismarx',
#       'name': 'Paris Marx',
#       'id': 23273872,
#       'id_str': '23273872',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1022702069159841792,
#     'id_str': '1022702069159841792',
#     'name': '🏳️\u200d⚧️BEET',
#     'screen_name': 'Gothigator',
#     'location': '🇨🇦',
#     'description': '~.*☆ ( He/They · 26 · Ambonec · Gay · Ace · Anarchist ) ☆*.~\nDNI: Minors, exclus, proship, tankies, the obvious.\nComms in Ko-Fi link.\n💕@timmoten',
#     'url': 'https://t.co/da4WlbAO0m',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/da4WlbAO0m',
#         'expanded_url': 'https://ko-fi.com/gothigator/commissions',
#         'display_url': 'ko-fi.com/gothigator/com…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 81,
#     'friends_count': 3401,
#     'listed_count': 1,
#     'created_at': 'Fri Jul 27 04:35:48 +0000 2018',
#     'favourites_count': 78593,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 59473,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1546155660055920642/QYLi01uW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1546155660055920642/QYLi01uW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1022702069159841792/1547268276',
#     'profile_link_color': 'F7AEE1',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 04 19:38:34 +0000 2022',
#     'id': 1588616716082462726,
#     'id_str': '1588616716082462726',
#     'text': 'Elon Musk is literally going to burn this website to the ground because extreme right-wing posters keep egging him… https://t.co/HqJDdmtlKy',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/HqJDdmtlKy',
#        'expanded_url': 'https://twitter.com/i/web/status/1588616716082462726',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 23273872,
#      'id_str': '23273872',
#      'name': 'Paris Marx',
#      'screen_name': 'parismarx',
#      'location': 'St. John’s, Canada',
#      'description': 'critic of tech futures | host @techwontsaveus | my book “road to nowhere” is out now: https://t.co/5m15LZT2Yr | they/he',
#      'url': 'https://t.co/lo1DQ5YUc7',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/lo1DQ5YUc7',
#          'expanded_url': 'http://parismarx.com',
#          'display_url': 'parismarx.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/5m15LZT2Yr',
#          'expanded_url': 'http://bit.ly/3PWF62T',
#          'display_url': 'bit.ly/3PWF62T',
#          'indices': [86, 109]}]}},
#      'protected': False,
#      'followers_count': 36049,
#      'friends_count': 633,
#      'listed_count': 538,
#      'created_at': 'Sun Mar 08 04:02:32 +0000 2009',
#      'favourites_count': 64612,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 44773,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '111111',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1552396140750032901/cv5BiZTH_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1552396140750032901/cv5BiZTH_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/23273872/1657025273',
#      'profile_link_color': 'DD0000',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'F3F3F3',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 31,
#     'favorite_count': 181,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 31,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 04 21:45:28 +0000 2022',
#    'id': 1588648650368245760,
#    'id_str': '1588648650368245760',
#    'text': 'RT @MovieHooligan: So, just to recap, there was nothing overtly wrong with Twitter before Elon Musk decided to buy it. He declared it broke…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MovieHooligan',
#       'name': 'David C Bell',
#       'id': 402817483,
#       'id_str': '402817483',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1055258533590118401,
#     'id_str': '1055258533590118401',
#     'name': 'tidalwaveofbluebirds',
#     'screen_name': 'tidalwaveofblu1',
#     'location': '',
#     'description': '24, She/Her, lurks and hardly tweets like a weirdo',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 45,
#     'friends_count': 920,
#     'listed_count': 3,
#     'created_at': 'Thu Oct 25 00:43:34 +0000 2018',
#     'favourites_count': 17829,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 152368,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1186149724274999296/neOqxcR0_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1186149724274999296/neOqxcR0_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1055258533590118401/1540428499',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 04 07:09:25 +0000 2022',
#     'id': 1588428185846579202,
#     'id_str': '1588428185846579202',
#     'text': 'So, just to recap, there was nothing overtly wrong with Twitter before Elon Musk decided to buy it. He declared it… https://t.co/H66l5aFZms',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/H66l5aFZms',
#        'expanded_url': 'https://twitter.com/i/web/status/1588428185846579202',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 402817483,
#      'id_str': '402817483',
#      'name': 'David C Bell',
#      'screen_name': 'MovieHooligan',
#      'location': 'Los Angeles, CA',
#      'description': 'Horse expert. Host & Co-Owner of @GamefullyUn. Head writer for @SomeMoreNews. Co-host of @BestBadMovieEv. Former editor for https://t.co/vl8V8Wayes.',
#      'url': 'https://t.co/zlnVKfNf9l',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/zlnVKfNf9l',
#          'expanded_url': 'https://www.patreon.com/GamefullyUnemployed',
#          'display_url': 'patreon.com/GamefullyUnemp…',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/vl8V8Wayes',
#          'expanded_url': 'http://Cracked.com',
#          'display_url': 'Cracked.com',
#          'indices': [124, 147]}]}},
#      'protected': False,
#      'followers_count': 14388,
#      'friends_count': 1660,
#      'listed_count': 123,
#      'created_at': 'Tue Nov 01 16:28:33 +0000 2011',
#      'favourites_count': 31074,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 9748,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/742071120371716097/DjfdrGuv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/742071120371716097/DjfdrGuv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/402817483/1352181904',
#      'profile_link_color': '009999',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1631,
#     'favorite_count': 20737,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1631,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 04 21:45:28 +0000 2022',
#    'id': 1588648650288566273,
#    'id_str': '1588648650288566273',
#    'text': 'RT @rashadrobinson: Elon Musk fired the entire team that identified that the Twitter algorithm amplifies right-wing voices over others. \n\nN…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rashadrobinson',
#       'name': 'Rashad Robinson',
#       'id': 21456548,
#       'id_str': '21456548',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1355965659352543234,
#     'id_str': '1355965659352543234',
#     'name': 'Ryebread Lover 🇩🇰🇺🇦',
#     'screen_name': 'LoverRyebread',
#     'location': 'Anti-pedoputin-land ',
#     'description': 'I just love rye bread. Glory to Ukraine! Officer of #NAFO - fighter of vatnicism.',
#     'url': 'https://t.co/AXBleWNJJa',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/AXBleWNJJa',
#         'expanded_url': 'https://www.m.tribel.com/RyeBreadab62226/wall',
#         'display_url': 'm.tribel.com/RyeBreadab6222…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1069,
#     'friends_count': 1616,
#     'listed_count': 4,
#     'created_at': 'Sun Jan 31 19:46:30 +0000 2021',
#     'favourites_count': 22181,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 9568,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1563924991451828226/V9hbuW_S_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1563924991451828226/V9hbuW_S_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1355965659352543234/1660978827',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 04 14:53:42 +0000 2022',
#     'id': 1588545026099154946,
#     'id_str': '1588545026099154946',
#     'text': 'Elon Musk fired the entire team that identified that the Twitter algorithm amplifies right-wing voices over others.… https://t.co/1N1LZPstFY',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/1N1LZPstFY',
#        'expanded_url': 'https://twitter.com/i/web/status/1588545026099154946',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 21456548,
#      'id_str': '21456548',
#      'name': 'Rashad Robinson',
#      'screen_name': 'rashadrobinson',
#      'location': 'New York City',
#      'description': "President @ColorOfChange, spokesperson @votingwhileblk, foodie and hat aficionado. Changing written & unwritten rules in media, tech, biz & gov't. Views my own.",
#      'url': 'https://t.co/A7uNOg8uWR',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/A7uNOg8uWR',
#          'expanded_url': 'http://colorofchange.org',
#          'display_url': 'colorofchange.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 74948,
#      'friends_count': 3170,
#      'listed_count': 861,
#      'created_at': 'Sat Feb 21 02:18:36 +0000 2009',
#      'favourites_count': 14356,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 24435,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1185323362018611201/qKyq2KiB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1185323362018611201/qKyq2KiB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21456548/1537045916',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7317,
#     'favorite_count': 23408,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7317,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 04 21:45:28 +0000 2022',
#    'id': 1588648650263400450,
#    'id_str': '1588648650263400450',
#    'text': 'RT @ericareport: BREAKING: Elon Musk has just fired the entire Human Rights team from Twitter.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ericareport',
#       'name': 'Erica Marsh',
#       'id': 1575205434843049984,
#       'id_str': '1575205434843049984',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 967498061269348352,
#     'id_str': '967498061269348352',
#     'name': 'Wolfgang. One Race: HUMAN.🇺🇸💙💛🙏🇺🇦🙏🌊🌊💙',
#     'screen_name': 'WolfgangRUL',
#     'location': 'FL🇺🇲💙🌊',
#     'description': 'Please follow me  👉🏾 https://t.co/ICCYNWvxSQ…',
#     'url': 'https://t.co/9Jk8iLnqC2',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/9Jk8iLnqC2',
#         'expanded_url': 'https://twitter.com/TribelSocial',
#         'display_url': 'twitter.com/TribelSocial',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/ICCYNWvxSQ',
#         'expanded_url': 'http://m.tribel.com/Wolf2eba6cd/wa',
#         'display_url': 'm.tribel.com/Wolf2eba6cd/wa',
#         'indices': [21, 44]}]}},
#     'protected': False,
#     'followers_count': 7534,
#     'friends_count': 7842,
#     'listed_count': 5,
#     'created_at': 'Sat Feb 24 20:34:47 +0000 2018',
#     'favourites_count': 228830,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 170398,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1506735461649297409/cK6k6-_K_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1506735461649297409/cK6k6-_K_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/967498061269348352/1653573548',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 04 18:53:36 +0000 2022',
#     'id': 1588605399540060160,
#     'id_str': '1588605399540060160',
#     'text': 'BREAKING: Elon Musk has just fired the entire Human Rights team from Twitter.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1575205434843049984,
#      'id_str': '1575205434843049984',
#      'name': 'Erica Marsh',
#      'screen_name': 'ericareport',
#      'location': 'Washington D.C. ',
#      'description': 'Proud Democrat: Former Field Organizer to elect President Biden, Volunteer for the Obama Foundation. (She/Her) 💙 @ericareport',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 29797,
#      'friends_count': 945,
#      'listed_count': 68,
#      'created_at': 'Wed Sep 28 19:27:03 +0000 2022',
#      'favourites_count': 377,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1128,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1582828230762934272/G0-VqYqB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1582828230762934272/G0-VqYqB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1575205434843049984/1666304755',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 14,
#     'favorite_count': 50,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 14,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 04 21:45:28 +0000 2022',
#    'id': 1588648650024312832,
#    'id_str': '1588648650024312832',
#    'text': "RT @robdaviau: I like how Elon Musk is speedrunning Brewster's Millions",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'robdaviau',
#       'name': 'Rob Daviau',
#       'id': 434912438,
#       'id_str': '434912438',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 92730014,
#     'id_str': '92730014',
#     'name': 'Walks without Rhythm',
#     'screen_name': 'SR_Chep',
#     'location': 'Argon Prime',
#     'description': 'Ex-forensic scientist, part time gamer, pro-Europe (I love the food) & baker. I had a cat. He had more willpower than me. He was also more suave than me.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 205,
#     'friends_count': 1017,
#     'listed_count': 7,
#     'created_at': 'Thu Nov 26 10:44:33 +0000 2009',
#     'favourites_count': 3986,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 11818,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '991C31',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/681960540432928772/FldIuwJW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/681960540432928772/FldIuwJW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/92730014/1521847832',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '333333',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 04 18:38:26 +0000 2022',
#     'id': 1588601581016055809,
#     'id_str': '1588601581016055809',
#     'text': "I like how Elon Musk is speedrunning Brewster's Millions",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 434912438,
#      'id_str': '434912438',
#      'name': 'Rob Daviau',
#      'screen_name': 'robdaviau',
#      'location': '',
#      'description': 'I make games, tell stories, play games, cook, sleep, enjoy food, enjoy wine, and live in a super blue state. https://t.co/dB0q208WPp',
#      'url': 'https://t.co/zgqaUu8m1z',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/zgqaUu8m1z',
#          'expanded_url': 'http://robdaviau.com',
#          'display_url': 'robdaviau.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/dB0q208WPp',
#          'expanded_url': 'http://www.robdaviau.com',
#          'display_url': 'robdaviau.com',
#          'indices': [109, 132]}]}},
#      'protected': False,
#      'followers_count': 13303,
#      'friends_count': 522,
#      'listed_count': 271,
#      'created_at': 'Mon Dec 12 13:24:13 +0000 2011',
#      'favourites_count': 10832,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 17460,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '022330',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/2382086898/h0pk8jdsv4gtnuo1j9jb_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2382086898/h0pk8jdsv4gtnuo1j9jb_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/434912438/1526289264',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'A8C7F7',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 8,
#     'favorite_count': 43,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 8,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 04 21:45:27 +0000 2022',
#    'id': 1588648647809724416,
#    'id_str': '1588648647809724416',
#    'text': 'RT @TTuiteroman: Twitter funciona por los tuiteros y tuiteras. \nElon Musk debería pagarnos 20 dólares al mes.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TTuiteroman',
#       'name': 'Bufff!',
#       'id': 970615196048936960,
#       'id_str': '970615196048936960',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2717307492,
#     'id_str': '2717307492',
#     'name': 'javiersm822@gmail.co',
#     'screen_name': 'nagual16',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1015,
#     'friends_count': 809,
#     'listed_count': 1,
#     'created_at': 'Fri Aug 08 15:28:13 +0000 2014',
#     'favourites_count': 131619,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 101360,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 04 21:36:55 +0000 2022',
#     'id': 1588646499113582592,
#     'id_str': '1588646499113582592',
#     'text': 'Twitter funciona por los tuiteros y tuiteras. \nElon Musk debería pagarnos 20 dólares al mes.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 970615196048936960,
#      'id_str': '970615196048936960',
#      'name': 'Bufff!',
#      'screen_name': 'TTuiteroman',
#      'location': '',
#      'description': 'Y yo qué sé!.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6023,
#      'friends_count': 564,
#      'listed_count': 21,
#      'created_at': 'Mon Mar 05 11:01:10 +0000 2018',
#      'favourites_count': 63450,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 50298,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1585648867902619648/Rw4gH-ZB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1585648867902619648/Rw4gH-ZB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/970615196048936960/1666883124',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
# ...
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 818893114979061761,
#      'id_str': '818893114979061761',
#      'name': 'Jo 🌻',
#      'screen_name': 'JoJoFromJerz',
#      'location': 'New Jersey, USA',
#      'description': 'jersey. dem. news junkie. Lebanese. hothead. mom. geek. co-founder @PillowFightCo. Blocked by Chachi. https://t.co/9Fp1kdOX6w https://t.co/OkMApgMVKU',
#      'url': 'https://t.co/2HDxAiXOtk',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/2HDxAiXOtk',
#          'expanded_url': 'https://www.patreon.com/JoJoFromJerz',
#          'display_url': 'patreon.com/JoJoFromJerz',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/9Fp1kdOX6w',
#          'expanded_url': 'https://ko-fi.com/jojofromjerz',
#          'display_url': 'ko-fi.com/jojofromjerz',
#          'indices': [102, 125]},
#         {'url': 'https://t.co/OkMApgMVKU',
#          'expanded_url': 'http://JoJoFromJerz.com',
#          'display_url': 'JoJoFromJerz.com',
#          'indices': [126, 149]}]}},
#      'protected': False,
#      'followers_count': 680448,
#      'friends_count': 4744,
#      'listed_count': 1781,
#      'created_at': 'Tue Jan 10 18:51:47 +0000 2017',
#      'favourites_count': 405600,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 145357,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1296043200633856004/nizJd4N1_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1296043200633856004/nizJd4N1_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/818893114979061761/1666447343',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1737,
#     'favorite_count': 19868,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1737,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 04 21:45:17 +0000 2022',
#    'id': 1588648603504898051,
#    'id_str': '1588648603504898051',
#    'text': 'RT @manuelhborbolla: Al cambiar el modelo de negocios de Twitter, es posible que la verdadera intención de Elon Musk sea acotar el alcance…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'manuelhborbolla',
#       'name': 'manuel hernández borbolla',
#       'id': 164762733,
#       'id_str': '164762733',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 24661045,
#     'id_str': '24661045',
#     'name': 'MiguelEnLaOdisea',
#     'screen_name': 'MiguelNLaOdisea',
#     'location': 'Mexico',
#     'description': 'IEC. Anti-Neoliberal. En busca de una verdadera Democracia y Justicia en México.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 737,
#     'friends_count': 895,
#     'listed_count': 0,
#     'created_at': 'Mon Mar 16 06:49:21 +0000 2009',
#     'favourites_count': 198794,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 160438,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1506844838200815619/TDN__5Uw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1506844838200815619/TDN__5Uw_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24661045/1356232314',
#     'profile_link_color': 'CC3300',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'F7DA93',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 04 20:01:00 +0000 2022',
#     'id': 1588622359174729728,
#     'id_str': '1588622359174729728',
#     'text': 'Al cambiar el modelo de negocios de Twitter, es posible que la verdadera intención de Elon Musk sea acotar el alcan… https://t.co/kTsgUffvO6',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/kTsgUffvO6',
#        'expanded_url': 'https://twitter.com/i/web/status/1588622359174729728',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 164762733,
#      'id_str': '164762733',
#      'name': 'manuel hernández borbolla',
#      'screen_name': 'manuelhborbolla',
#      'location': '',
#      'description': 'Periodista y poeta. Reportero en México de @ActualidadRT.\nNaturaleza, arte y política. Premio Alemán de Periodismo WR 2014; Premio Nacional de Periodismo 2020.',
#      'url': 'https://t.co/QdkVYvxvBM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/QdkVYvxvBM',
#          'expanded_url': 'https://www.youtube.com/c/manuelhernandezborbolla',
#          'display_url': 'youtube.com/c/manuelhernan…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 56936,
#      'friends_count': 1855,
#      'listed_count': 320,
#      'created_at': 'Fri Jul 09 17:57:16 +0000 2010',
#      'favourites_count': 7637,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 28419,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/991900050845401089/c1X6P-ZX_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/991900050845401089/c1X6P-ZX_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/164762733/1421638649',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 13,
#     'favorite_count': 44,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'es'},
#    'is_quote_status': False,
#    'retweet_count': 13,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'es'},
#   {'created_at': 'Fri Nov 04 21:45:17 +0000 2022',
#    'id': 1588648603438182401,
#    'id_str': '1588648603438182401',
#    'text': 'RT @DougJBalloon: Times have been tough in this Ohio town ever since the woke mob shut down the old rainbow fentanyl factory.  So when Elon…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DougJBalloon',
#       'name': 'New York Times Pitchbot',
#       'id': 22998311,
#       'id_str': '22998311',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 108127637,
#     'id_str': '108127637',
#     'name': 'Foxy Knitter',
#     'screen_name': 'foxyknitter',
#     'location': 'Chicago, IL',
#     'description': 'You may be forced to do ugly things, but you can always do them with style. Hyde Park/Kenwood, Chicago, IL.',
#     'url': 'https://t.co/wcCBUz8RR8',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/wcCBUz8RR8',
#         'expanded_url': 'http://www.foxyknitter.com',
#         'display_url': 'foxyknitter.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 276,
#     'friends_count': 1529,
#     'listed_count': 29,
#     'created_at': 'Sun Jan 24 23:24:23 +0000 2010',
#     'favourites_count': 95696,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 42111,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/810166489953275904/3shnw_cW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/810166489953275904/3shnw_cW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/108127637/1516910631',
#     'profile_link_color': '94D487',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 04 20:12:15 +0000 2022',
#     'id': 1588625190598062080,
#     'id_str': '1588625190598062080',
#     'text': 'Times have been tough in this Ohio town ever since the woke mob shut down the old rainbow fentanyl factory.  So whe… https://t.co/24z2poBwLi',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/24z2poBwLi',
#        'expanded_url': 'https://twitter.com/i/web/status/1588625190598062080',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 22998311,
#      'id_str': '22998311',
#      'name': 'New York Times Pitchbot',
#      'screen_name': 'DougJBalloon',
#      'location': '',
#      'description': 'Parody. Staying here for now but maybe not much longer.  Merch: https://t.co/3bxNPhuVHj',
#      'url': 'https://t.co/hmqH4NSQBW',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/hmqH4NSQBW',
#          'expanded_url': 'http://www.balloon-juice.com',
#          'display_url': 'balloon-juice.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/3bxNPhuVHj',
#          'expanded_url': 'http://stores.inksoft.com/nytpitchbot',
#          'display_url': 'stores.inksoft.com/nytpitchbot',
#          'indices': [64, 87]}]}},
#      'protected': False,
#      'followers_count': 214450,
#      'friends_count': 3638,
#      'listed_count': 926,
#      'created_at': 'Thu Mar 05 23:35:29 +0000 2009',
#      'favourites_count': 44149,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 69672,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1449034383420182531/Ava9u8mK_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1449034383420182531/Ava9u8mK_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22998311/1663813530',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 622,
#     'favorite_count': 3280,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 622,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.146,
#   'max_id': 1588648653081792513,
#   'max_id_str': '1588648653081792513',
#   'next_results': '?max_id=1588648603438182400&q=Elon%20Musk&count=100&include_entities=1',
#   'query': 'Elon+Musk',
#   'refresh_url': '?since_id=1588648653081792513&q=Elon%20Musk&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
all_items=results['statuses']

# %%
df=pd.DataFrame(all_items)

# %%
df
# Out:
#                         created_at                   id               id_str  \
# 0   Fri Nov 04 21:45:29 +0000 2022  1588648653081792513  1588648653081792513
# 1   Fri Nov 04 21:45:29 +0000 2022  1588648653010395142  1588648653010395142
# 2   Fri Nov 04 21:45:28 +0000 2022  1588648650770874368  1588648650770874368
# 3   Fri Nov 04 21:45:28 +0000 2022  1588648650368245760  1588648650368245760
# 4   Fri Nov 04 21:45:28 +0000 2022  1588648650288566273  1588648650288566273
# ..                             ...                  ...                  ...
# 95  Fri Nov 04 21:45:17 +0000 2022  1588648605199785984  1588648605199785984
# 96  Fri Nov 04 21:45:17 +0000 2022  1588648604046348289  1588648604046348289
# 97  Fri Nov 04 21:45:17 +0000 2022  1588648603798704129  1588648603798704129
# 98  Fri Nov 04 21:45:17 +0000 2022  1588648603504898051  1588648603504898051
# 99  Fri Nov 04 21:45:17 +0000 2022  1588648603438182401  1588648603438182401
#
#                                                  text  truncated  \
# 0   RT @MattNegrin: Elon Musk is 72 hours away fro...      False
# 1   RT @gevnesis: atropelaria bolsonaristas e o el...      False
# 2   RT @parismarx: Elon Musk is literally going to...      False
# 3   RT @MovieHooligan: So, just to recap, there wa...      False
# 4   RT @rashadrobinson: Elon Musk fired the entire...      False
# ..                                                ...        ...
# 95  イーロンマスク氏、活動家グループによる広告主への圧力によりTwitter社の収益が大幅に減少...       True
# 96  Do you guys think Elon Musk would like the pin...      False
# 97  RT @JoJoFromJerz: I’m beginning to think maybe...      False
# 98  RT @manuelhborbolla: Al cambiar el modelo de n...      False
# 99  RT @DougJBalloon: Times have been tough in thi...      False
#
#                                              entities  \
# 0   {'hashtags': [], 'symbols': [], 'user_mentions...
# 1   {'hashtags': [], 'symbols': [], 'user_mentions...
# 2   {'hashtags': [], 'symbols': [], 'user_mentions...
# 3   {'hashtags': [], 'symbols': [], 'user_mentions...
# 4   {'hashtags': [], 'symbols': [], 'user_mentions...
# ..                                                ...
# 95  {'hashtags': [], 'symbols': [], 'user_mentions...
# 96  {'hashtags': [], 'symbols': [], 'user_mentions...
# 97  {'hashtags': [], 'symbols': [], 'user_mentions...
# 98  {'hashtags': [], 'symbols': [], 'user_mentions...
# 99  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                              metadata  \
# 0   {'iso_language_code': 'en', 'result_type': 're...
# 1   {'iso_language_code': 'pt', 'result_type': 're...
# 2   {'iso_language_code': 'en', 'result_type': 're...
# 3   {'iso_language_code': 'en', 'result_type': 're...
# 4   {'iso_language_code': 'en', 'result_type': 're...
# ..                                                ...
# 95  {'iso_language_code': 'ja', 'result_type': 're...
# 96  {'iso_language_code': 'en', 'result_type': 're...
# 97  {'iso_language_code': 'en', 'result_type': 're...
# 98  {'iso_language_code': 'es', 'result_type': 're...
# 99  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                source  in_reply_to_status_id  \
# 0   <a href="http://tapbots.com/tweetbot" rel="nof...                    NaN
# 1   <a href="http://twitter.com/download/android" ...                    NaN
# 2   <a href="http://twitter.com/download/android" ...                    NaN
# 3   <a href="http://twitter.com/download/iphone" r...                    NaN
# 4   <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# ..                                                ...                    ...
# 95  <a href="http://twitter.com/download/iphone" r...                    NaN
# 96  <a href="http://twitter.com/download/iphone" r...                    NaN
# 97  <a href="http://twitter.com/download/iphone" r...                    NaN
# 98  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 99  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    in_reply_to_status_id_str  ...  retweet_count favorite_count favorited  \
# 0                       None  ...            244              0     False
# 1                       None  ...              1              0     False
# 2                       None  ...             31              0     False
# 3                       None  ...           1631              0     False
# 4                       None  ...           7317              0     False
# ..                       ...  ...            ...            ...       ...
# 95                      None  ...              0              0     False
# 96                      None  ...              0              0     False
# 97                      None  ...           1737              0     False
# 98                      None  ...             13              0     False
# 99                      None  ...            622              0     False
#
#    retweeted lang possibly_sensitive quoted_status_id quoted_status_id_str  \
# 0      False   en                NaN              NaN                  NaN
# 1      False   pt                NaN              NaN                  NaN
# 2      False   en                NaN              NaN                  NaN
# 3      False   en                NaN              NaN                  NaN
# 4      False   en                NaN              NaN                  NaN
# ..       ...  ...                ...              ...                  ...
# 95     False   ja              False     1.588539e+18  1588538640401018880
# 96     False   en              False              NaN                  NaN
# 97     False   en                NaN              NaN                  NaN
# 98     False   es                NaN              NaN                  NaN
# 99     False   en                NaN              NaN                  NaN
#
#                                     extended_entities  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96  {'media': [{'id': 1588648595435266049, 'id_str...
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                         quoted_status
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95  {'created_at': 'Fri Nov 04 14:28:20 +0000 2022...
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
# [100 rows x 30 columns]

# %%
users=pd.DataFrame(d["user"] for d in results["statuses"])

# %%
users.head()
# Out:
#                     id               id_str                          name  \
# 0             15617390             15617390                      Navesink
# 1  1469983438585409537  1469983438585409537  Luis Felipe Fonseca Da Costa
# 2  1022702069159841792  1022702069159841792                     🏳️‍⚧️BEET
# 3  1055258533590118401  1055258533590118401          tidalwaveofbluebirds
# 4  1355965659352543234  1355965659352543234           Ryebread Lover 🇩🇰🇺🇦
#
#        screen_name                      location  \
# 0         Navesink  iPhone: 40.416885,-74.036148
# 1  LuisFel19833407                    Belém,Pará
# 2       Gothigator                            🇨🇦
# 3  tidalwaveofblu1
# 4    LoverRyebread          Anti-pedoputin-land
#
#                                          description                      url  \
# 0  Sam Posten - Software Engineer, Photographer, ...  https://t.co/eFBP9jFWxn
# 1      🦸🏻‍♂️🌎Para o Alto e Avante/Up,Up And Away✝️🇧🇷  https://t.co/xFIyTPevqF
# 2  ~.*☆ ( He/They · 26 · Ambonec · Gay · Ace · An...  https://t.co/da4WlbAO0m
# 3  24, She/Her, lurks and hardly tweets like a we...                     None
# 4  I just love rye bread. Glory to Ukraine! Offic...  https://t.co/AXBleWNJJa
#
#                                             entities  protected  \
# 0  {'url': {'urls': [{'url': 'https://t.co/eFBP9j...      False
# 1  {'url': {'urls': [{'url': 'https://t.co/xFIyTP...      False
# 2  {'url': {'urls': [{'url': 'https://t.co/da4Wlb...      False
# 3                      {'description': {'urls': []}}      False
# 4  {'url': {'urls': [{'url': 'https://t.co/AXBleW...      False
#
#    followers_count  ...  profile_text_color  profile_use_background_image  \
# 0              819  ...              333333                          True
# 1             2493  ...              333333                          True
# 2               81  ...              000000                         False
# 3               45  ...              333333                          True
# 4             1069  ...              333333                          True
#
#   has_extended_profile  default_profile default_profile_image following  \
# 0                False            False                 False      None
# 1                 True             True                 False      None
# 2                 True            False                 False      None
# 3                 True             True                 False      None
# 4                 True             True                 False      None
#
#    follow_request_sent  notifications  translator_type withheld_in_countries
# 0                 None           None             none                    []
# 1                 None           None             none                    []
# 2                 None           None             none                    []
# 3                 None           None             none                    []
# 4                 None           None             none                    []
#
# [5 rows x 43 columns]

# %%
tdf=df.merge(users,left_index=True,right_index=True)

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 73 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   created_at_x                        100 non-null    object
#  1   id_x                                100 non-null    int64
#  2   id_str_x                            100 non-null    object
#  3   text                                100 non-null    object
#  4   truncated                           100 non-null    bool
#  5   entities_x                          100 non-null    object
#  6   metadata                            100 non-null    object
#  7   source                              100 non-null    object
#  8   in_reply_to_status_id               3 non-null      float64
#  9   in_reply_to_status_id_str           3 non-null      object
#  10  in_reply_to_user_id                 3 non-null      float64
#  11  in_reply_to_user_id_str             3 non-null      object
#  12  in_reply_to_screen_name             3 non-null      object
#  13  user                                100 non-null    object
#  14  geo                                 0 non-null      object
#  15  coordinates                         0 non-null      object
#  16  place                               0 non-null      object
#  17  contributors                        0 non-null      object
#  18  retweeted_status                    83 non-null     object
#  19  is_quote_status                     100 non-null    bool
#  20  retweet_count                       100 non-null    int64
#  21  favorite_count                      100 non-null    int64
#  22  favorited                           100 non-null    bool
#  23  retweeted                           100 non-null    bool
#  24  lang_x                              100 non-null    object
#  25  possibly_sensitive                  13 non-null     object
#  26  quoted_status_id                    5 non-null      float64
#  27  quoted_status_id_str                5 non-null      object
#  28  extended_entities                   3 non-null      object
#  29  quoted_status                       1 non-null      object
#  30  id_y                                100 non-null    int64
#  31  id_str_y                            100 non-null    object
#  32  name                                100 non-null    object
#  33  screen_name                         100 non-null    object
#  34  location                            100 non-null    object
#  35  description                         100 non-null    object
#  36  url                                 28 non-null     object
#  37  entities_y                          100 non-null    object
#  38  protected                           100 non-null    bool
#  39  followers_count                     100 non-null    int64
#  40  friends_count                       100 non-null    int64
#  41  listed_count                        100 non-null    int64
#  42  created_at_y                        100 non-null    object
#  43  favourites_count                    100 non-null    int64
#  44  utc_offset                          0 non-null      object
#  45  time_zone                           0 non-null      object
#  46  geo_enabled                         100 non-null    bool
#  47  verified                            100 non-null    bool
#  48  statuses_count                      100 non-null    int64
#  49  lang_y                              0 non-null      object
#  50  contributors_enabled                100 non-null    bool
#  51  is_translator                       100 non-null    bool
#  52  is_translation_enabled              100 non-null    bool
#  53  profile_background_color            100 non-null    object
#  54  profile_background_image_url        53 non-null     object
#  55  profile_background_image_url_https  53 non-null     object
#  56  profile_background_tile             100 non-null    bool
#  57  profile_image_url                   100 non-null    object
#  58  profile_image_url_https             100 non-null    object
#  59  profile_banner_url                  82 non-null     object
#  60  profile_link_color                  100 non-null    object
#  61  profile_sidebar_border_color        100 non-null    object
#  62  profile_sidebar_fill_color          100 non-null    object
#  63  profile_text_color                  100 non-null    object
#  64  profile_use_background_image        100 non-null    bool
#  65  has_extended_profile                100 non-null    bool
#  66  default_profile                     100 non-null    bool
#  67  default_profile_image               100 non-null    bool
#  68  following                           0 non-null      object
#  69  follow_request_sent                 0 non-null      object
#  70  notifications                       0 non-null      object
#  71  translator_type                     100 non-null    object
#  72  withheld_in_countries               100 non-null    object
# dtypes: bool(15), float64(3), int64(9), object(46)
# memory usage: 46.9+ KB

# %%
tdf.location.value_counts().plot(kind='bar',figsize=(10,6))
# Out:
# <AxesSubplot:>
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127482 (\N{REGIONAL INDICATOR SYMBOL LETTER U}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127480 (\N{REGIONAL INDICATOR SYMBOL LETTER S}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127464 (\N{REGIONAL INDICATOR SYMBOL LETTER C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127462 (\N{REGIONAL INDICATOR SYMBOL LETTER A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127474 (\N{REGIONAL INDICATOR SYMBOL LETTER M}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128153 (\N{BLUE HEART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127754 (\N{WATER WAVE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127866 (\N{BEER MUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127956 (\N{SNOW CAPPED MOUNTAIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\T\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127469 (\N{REGIONAL INDICATOR SYMBOL LETTER H}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from textblob import TextBlob

# %%
def detect_sentiment(text):
    return TextBlob(text).sentiment.polarity

# %%
df2=tdf[["text"]]

# %%
df2.head()
# Out:
#                                                 text
# 0  RT @MattNegrin: Elon Musk is 72 hours away fro...
# 1  RT @gevnesis: atropelaria bolsonaristas e o el...
# 2  RT @parismarx: Elon Musk is literally going to...
# 3  RT @MovieHooligan: So, just to recap, there wa...
# 4  RT @rashadrobinson: Elon Musk fired the entire...

# %%
df2["sentiment"]=df2["text"].apply(detect_sentiment)
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_9572\1909004749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["sentiment"]=df2["text"].apply(detect_sentiment)

# %%
df2.head()
# Out:
#                                                 text  sentiment
# 0  RT @MattNegrin: Elon Musk is 72 hours away fro...      0.200
# 1  RT @gevnesis: atropelaria bolsonaristas e o el...      0.000
# 2  RT @parismarx: Elon Musk is literally going to...     -0.125
# 3  RT @MovieHooligan: So, just to recap, there wa...     -0.500
# 4  RT @rashadrobinson: Elon Musk fired the entire...      0.000

# %%
df2.sentiment.value_counts()
# Out:
#  0.000000    53
#  0.100000     6
#  0.200000     3
# -0.500000     3
#  0.300000     3
# -0.400000     3
# -0.200000     2
# -0.800000     2
#  0.350000     2
# -0.125000     2
# -0.148148     2
#  0.300000     1
#  0.600000     1
#  0.250000     1
#  0.700000     1
# -0.375000     1
# -0.113333     1
#  0.033333     1
#  0.500000     1
# -0.025000     1
#  0.136364     1
#  0.050000     1
# -0.050000     1
#  0.068182     1
#  0.170000     1
#  0.083333     1
#  0.433333     1
#  0.168333     1
# -0.155556     1
#  0.910000     1
# Name: sentiment, dtype: int64

# %%
df2["text"]=df2["text"].str.lower()
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_9572\1934567259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.lower()

# %%
df2["text"]=df2["text"].str.replace("[^\w\s]","")
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_9572\265055035.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2["text"]=df2["text"].str.replace("[^\w\s]","")
# C:\Users\T\AppData\Local\Temp\ipykernel_9572\265055035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.replace("[^\w\s]","")

# %%
df2["text"]=df2["text"].str.replace("\d+","")
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_9572\1924162430.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2["text"]=df2["text"].str.replace("\d+","")
# C:\Users\T\AppData\Local\Temp\ipykernel_9572\1924162430.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.replace("\d+","")

# %%
df2["text"]=df2["text"].str.replace("\n"," ").replace("\r"," ")
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_9572\892400714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.replace("\n"," ").replace("\r"," ")

# %%
from wordcloud import STOPWORDS
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
def wc(data,bgcolor):
    plt.figure(figsize=(10,10))
    mask=np.array(Image.open("Elon.png"))
    wc=WordCloud(background_color=bgcolor,stopwords=STOPWORDS,mask=mask)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis("off")

# %%
wc(df2.text,'black')

# %%
#1=positive
#2 negative
#0 Neutral
def sentiment2(sent):
    if sent< -0.02:
        return 2
    elif sent> 0.02:
        return 1
    else:
        return 0

# %%
df2["sent"]=df2["sentiment"].apply(sentiment2)
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_9572\3383788003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["sent"]=df2["sentiment"].apply(sentiment2)

# %%
df2.head()
# Out:
#                                                 text  sentiment  sent
# 0  rt mattnegrin elon musk is  hours away from go...      0.200     1
# 1  rt gevnesis atropelaria bolsonaristas e o elon...      0.000     0
# 2  rt parismarx elon musk is literally going to b...     -0.125     2
# 3  rt moviehooligan so just to recap there was no...     -0.500     2
# 4  rt rashadrobinson elon musk fired the entire t...      0.000     0

# %%
import seaborn as sns

# %%
sns.countplot(x=df2.sent);

# %%
x=df2.text
y=df2.sent

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
vect=CountVectorizer(stop_words="english")

# %%
x=vect.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=.15)

# %%
mb=MultinomialNB()

# %%
tahmin=mb.fit(x_train,y_train).predict(x_test)

# %%
accuracy_score(tahmin,y_test)
# Out:
# 0.6666666666666666

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
d=DecisionTreeClassifier()

# %%
d.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tahmin2=d.predict(x_test)

# %%
accuracy_score(tahmin2,y_test)
# Out:
# 0.6
